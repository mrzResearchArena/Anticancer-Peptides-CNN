# %% [markdown]
# <a href="https://colab.research.google.com/github/mrzResearchArena/Anticancer-Peptides-CNN/blob/master/ACP-740-ROC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### [1]. Google Drive Initialization:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd 'drive/My Drive/ACP-PyFeat'
# Out:
# /content/drive/My Drive/ACP-PyFeat

# %%
ls
# Out:
# bits-164.npy    blosum-500.npy  model-240.png      PyFeat-500-20.npy
# bits-240.npy    blosum-740.npy  model-740.png      PyFeat-500.npy
# bits-500.npy    bpf-164.npy     PyFeat-164-20.npy  PyFeat-740-20.npy
# bits-740.npy    bpf-240.npy     PyFeat-164.npy     PyFeat-740.npy
# blosum-164.npy  bpf-500.npy     PyFeat-240-20.npy  ROC-240.png
# blosum-240.npy  bpf-740.npy     PyFeat-240.npy     ROC.png

# %% [markdown]
# ### [2]. Load Deep Learning API (Keras):

# %%
# # Initialize TF-2.x:
# try:
#     %tensorflow_version 2.x  # Colab only.
# except Exception:
#     pass

# import tensorflow as tf
# print('We\'re using TF-{}.'.format(tf.__version__))

# # Colab Auto Click: [https://paste.ubuntu.com/p/R78fGBJbjb/]

# %%
# Deep Neural Networks:
import tensorflow as tf; print('We\'re using TF-{}.'.format(tf.__version__))
# import keras; print('We\'re using Keras-{}.'.format(keras.__version__))
from tensorflow.keras.layers import (Input, Dense, Dropout, Flatten, BatchNormalization,
                                     Conv1D, Conv2D, MaxPooling1D, MaxPooling2D,
                                     LSTM, GRU, Embedding, Bidirectional, Concatenate)
from tensorflow.keras.regularizers import (l1, l2, l1_l2)
from tensorflow.keras.optimizers import (RMSprop, Adam, SGD)
from tensorflow.keras.models import (Sequential, Model)

# Core:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import interp
import matplotlib.patches as patches

# Performance:
from sklearn.metrics import (confusion_matrix, classification_report, matthews_corrcoef, precision_score, roc_curve, auc)
from sklearn.model_selection import (StratifiedKFold, KFold, train_test_split)

#Utilities:
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import to_categorical as labelEncoding   # Usages: Y = labelEncoding(Y, dtype=int)
from tensorflow.keras.utils import plot_model                        # Usages: plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=False, expand_nested=True)

#end-import
# Out:
# We're using TF-2.3.0.

# %%
def lossPlot(results):
    plt.title(label='Loss: Training and Validation')
    plt.plot(results.history['loss'], label='Training Loss')
    plt.plot(results.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
#end-def

def accuracyPlot(results):
    plt.title(label='Accuracy: Training and Validation')
    plt.plot(results.history['accuracy'], label='Training Accuracy')
    plt.plot(results.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()
#end-def

# %%
def rocPlot(TPR, meanFPR):
    plt.plot([0,1], [0,1],linestyle = '--',lw = 2,color = 'black')
    meanTPR = np.mean(TPR, axis=0)
    meanAUC = auc(meanFPR, meanTPR)
    plt.plot(meanFPR, meanTPR, color='blue',
            label=r'Mean ROC (AUC = %0.2f )' % (meanAUC),lw=2, alpha=1)

    plt.xlabel('False Positive Rate (FPR)')
    plt.ylabel('True Positive Rate (TPR)')
    plt.title('Receiver Operating Characteristic Curve (ROC Curve)')
    plt.legend(loc="lower right")
    plt.savefig('ROC-740.png')
    plt.show()
#end-def

# %% [markdown]
# ### [3]. Load Datasets:

# %%
T = 15 # terminus_length

X1 = np.load('bpf-740.npy')
X2 = np.load('bits-740.npy')
X3 = np.load('blosum-740.npy')


X1 = X1[:,0:T,:]
X2 = X2[:,0:T,:]
X3 = X3[:,0:T,:]


Y  = [1 for _ in range(376)]
Y += [0 for _ in range(364)]

Y = labelEncoding(Y, dtype=int)


print(X1.shape)
print(X2.shape)
print(X3.shape)
print(Y.shape)
# Out:
# (740, 15, 20)
# (740, 15, 31)
# (740, 15, 20)
# (740, 2)

# %% [markdown]
# ### [4]. Generate Model:

# %%
### Model-740

def Network():
    ### Head-1:
    input1 = Input(shape=X1[0].shape)

    x = Conv1D(filters=10, kernel_size=4, padding='same', activation='relu', kernel_regularizer=l2(l=0.01))(input1)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.80)(x)

    x = Conv1D(filters=8, kernel_size=3, padding='same', activation='relu', kernel_regularizer=l2(l=0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.70)(x)

    head1 = Flatten()(x)


    ### Head-2:
    input2 = Input(shape=X2[0].shape)

    x = Conv1D(filters=10, kernel_size=4, padding='same', activation='relu', kernel_regularizer=l2(l=0.01))(input2)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.70)(x)

    x = Conv1D(filters=8, kernel_size=3, padding='same', activation='relu', kernel_regularizer=l2(l=0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.70)(x)

    head2 = Flatten()(x)


    ### Head-3:
    input3 = Input(shape=X3[0].shape)
    
    x = Conv1D(filters=10, kernel_size=4, padding='same', activation='relu',)(input3)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.70)(x)

    x = Conv1D(filters=8, kernel_size=3, padding='same', activation='relu', kernel_regularizer=l2(l=0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.70)(x)

    head3 = Flatten()(x)


    # merge
    merge = Concatenate()([head1, head2, head3])

    output = Dense(units=8, activation='relu', kernel_regularizer=l2(l=0.01))(merge)
    output = BatchNormalization()(output)
    output = Dropout(rate=0.70)(output)

    output = Dense(units=2, activation='softmax')(output)

    return Model(inputs=[input1, input2, input3], outputs=[output])
#end-def

# %%
model = Network()
model.summary()
plot_model(model, to_file='model-740.png', show_shapes=True, show_layer_names=False, expand_nested=True)
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 15, 20)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 15, 31)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 15, 20)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 15, 10)       810         input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 15, 10)       1250        input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 15, 10)       810         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 15, 10)       40          conv1d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 15, 10)       40          conv1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 15, 10)       40          conv1d_4[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 15, 10)       0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 15, 10)       0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 15, 10)       0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 15, 8)        248         dropout[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 15, 8)        248         dropout_2[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 15, 8)        248         dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 15, 8)        32          conv1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 15, 8)        32          conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 15, 8)        32          conv1d_5[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 15, 8)        0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 15, 8)        0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 15, 8)        0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 120)          0           dropout_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 120)          0           dropout_3[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 120)          0           dropout_5[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 360)          0           flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 8)            2888        concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8)            32          dense[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 8)            0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            18          dropout_6[0][0]
# ==================================================================================================
# Total params: 6,768
# Trainable params: 6,644
# Non-trainable params: 124
# __________________________________________________________________________________________________

# %% [markdown]
# ### [5]. Run Model:

# %%
setEpochNumber     = 500     # Performed-welled in epoch 600.
setBatchSizeNumber = 8
####################################################

cv = KFold(n_splits=5, shuffle=True, random_state=101)

Accuracy = []
Sensitivity = []
Specificity = []
Precision = []
MCC = []

# ROC Curve:
fig1 = plt.figure(figsize=[12,12])

TPR = []
meanFPR = np.linspace(0, 1, 100)

i = 1

# CM = np.array([
#      [0, 0],
#      [0, 0],
# ], dtype=int)

for train, test in cv.split(Y):

    # Compile Model:
    model = Network()
    model.compile(optimizer=Adam(lr=0.005),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    # Run Model:
    results = model.fit(x=[X1[train,:,:], X2[train,:,:], X3[train,:,:]],
                        y=Y[train,:],
                        validation_data=([X1[test,:,:], X2[test,:,:], X3[test,:,:],], Y[test,:]),
                        batch_size=setBatchSizeNumber, epochs=setEpochNumber,
                        verbose=1,
                        callbacks=[])

    # Evaluate the Model:
    accuracy = model.evaluate(x=[X1[test,:,:], X2[test,:,:], X3[test,:,:]], y=Y[test,:])
    Accuracy.append(accuracy[1])
    
    # Performance Metices:
    Yactual = Y[test,:].argmax(axis=1)
    Yp = model.predict([X1[test,:,:], X2[test,:,:], X3[test,:,:]])
    v = Yp
    Yp = Yp.argmax(axis=1)

    CM = confusion_matrix(y_pred=Yp, y_true=Yactual)
    TN, FP, FN, TP = CM.ravel()

    MCC.append(matthews_corrcoef(y_true=Yactual, y_pred=Yp))
    Sensitivity.append( TP / (TP + FN) )
    Specificity.append( TN / (TN + FP) )
    Precision.append(precision_score(y_true=Yactual, y_pred=Yp))
    
    # ROC Curve
    fpr, tpr, _ = roc_curve(Yactual, v[:,1])
    TPR.append(interp(meanFPR, fpr, tpr))
    rocauc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, alpha=0.3, label='ROC fold %d (AUC = %0.2f)' % (i, rocauc))
    i= i+1
    
    # # Performance Plot
    # print('#################################################')
    # print('Fold\'s Accuracy: {:.2f}'.format(accuracy[1]*100.0))
    # lossPlot(results)
    # accuracyPlot(results)
    # print('#################################################')

#end-for

rocPlot(TPR, meanFPR)

print(Accuracy)
print('Accuracy: {:.2f}'.format(np.sum(Accuracy)/5.0))
print('Sensitivity: {0:.4f}'.format(np.sum(Sensitivity)/5.00))
print('Specificity: {0:.4f}'.format(np.sum(Specificity)/5.00))
print('MCC: {0:.4f}'.format(np.sum(MCC)/5.00))
print('Precision: {0:.4f}'.format(np.sum(Precision)/5.00))
# Out:
# Epoch 1/500
# 74/74 [==============================] - 1s 11ms/step - loss: 1.7053 - accuracy: 0.5169 - val_loss: 1.3822 - val_accuracy: 0.5000
# Epoch 2/500
# 74/74 [==============================] - 0s 6ms/step - loss: 1.4142 - accuracy: 0.4949 - val_loss: 1.3127 - val_accuracy: 0.4932
# Epoch 3/500
# 74/74 [==============================] - 1s 7ms/step - loss: 1.2738 - accuracy: 0.5236 - val_loss: 1.2199 - val_accuracy: 0.4932
# Epoch 4/500
# 74/74 [==============================] - 0s 6ms/step - loss: 1.1947 - accuracy: 0.5253 - val_loss: 1.1480 - val_accuracy: 0.4932
# Epoch 5/500
# 74/74 [==============================] - 1s 7ms/step - loss: 1.1080 - accuracy: 0.5405 - val_loss: 1.0701 - val_accuracy: 0.4797
# Epoch 6/500
# 74/74 [==============================] - 0s 7ms/step - loss: 1.0259 - accuracy: 0.5895 - val_loss: 1.0161 - val_accuracy: 0.5338
# Epoch 7/500
# 74/74 [==============================] - 1s 7ms/step - loss: 0.9908 - accuracy: 0.6098 - val_loss: 0.9584 - val_accuracy: 0.6014
# Epoch 8/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.9692 - accuracy: 0.5760 - val_loss: 0.9454 - val_accuracy: 0.6014
# Epoch 9/500
# 74/74 [==============================] - 1s 7ms/step - loss: 0.9105 - accuracy: 0.6419 - val_loss: 0.8896 - val_accuracy: 0.6284
# Epoch 10/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.8866 - accuracy: 0.6216 - val_loss: 0.9081 - val_accuracy: 0.5405
# Epoch 11/500
# 74/74 [==============================] - 1s 7ms/step - loss: 0.8919 - accuracy: 0.6351 - val_loss: 0.8538 - val_accuracy: 0.7095
# Epoch 12/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.8874 - accuracy: 0.6064 - val_loss: 0.8118 - val_accuracy: 0.7838
# Epoch 13/500
# 74/74 [==============================] - 1s 7ms/step - loss: 0.8400 - accuracy: 0.6672 - val_loss: 0.8139 - val_accuracy: 0.7297
# Epoch 14/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.8531 - accuracy: 0.6318 - val_loss: 0.8078 - val_accuracy: 0.7297
# Epoch 15/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.8556 - accuracy: 0.6132 - val_loss: 0.7958 - val_accuracy: 0.8041
# Epoch 16/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.8429 - accuracy: 0.6520 - val_loss: 0.7588 - val_accuracy: 0.7703
# Epoch 17/500
# 74/74 [==============================] - 1s 7ms/step - loss: 0.
500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6096 - accuracy: 0.7652 - val_loss: 0.5602 - val_accuracy: 0.8041
# Epoch 235/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6153 - accuracy: 0.7669 - val_loss: 0.5672 - val_accuracy: 0.7905
# Epoch 236/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6423 - accuracy: 0.7534 - val_loss: 0.5509 - val_accuracy: 0.7973
# Epoch 237/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6350 - accuracy: 0.7449 - val_loss: 0.5542 - val_accuracy: 0.8176
# Epoch 238/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6046 - accuracy: 0.7669 - val_loss: 0.5393 - val_accuracy: 0.8041
# Epoch 239/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6253 - accuracy: 0.7517 - val_loss: 0.5300 - val_accuracy: 0.8176
# Epoch 240/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6393 - accuracy: 0.7838 - val_loss: 0.5480 - val_accuracy: 0.8041
# Epoch 241/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6206 - accuracy: 0.7703 - val_loss: 0.5268 - val_accuracy: 0.8108
# Epoch 242/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6271 - accuracy: 0.7348 - val_loss: 0.5400 - val_accuracy: 0.8243
# Epoch 243/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.5990 - accuracy: 0.7686 - val_loss: 0.5448 - val_accuracy: 0.8108
# Epoch 244/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6329 - accuracy: 0.7500 - val_loss: 0.5426 - val_accuracy: 0.8378
# Epoch 245/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6436 - accuracy: 0.7466 - val_loss: 0.5404 - val_accuracy: 0.8041
# Epoch 246/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6477 - accuracy: 0.7280 - val_loss: 0.5465 - val_accuracy: 0.8176
# Epoch 247/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6052 - accuracy: 0.7483 - val_loss: 0.5302 - val_accuracy: 0.8176
# Epoch 248/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6174 - accuracy: 0.7365 - val_loss: 0.5542 - val_accuracy: 0.8041
# Epoch 249/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6334 - accuracy: 0.7568 - val_loss: 0.5566 - val_accuracy: 0.8041
# Epoch 250/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6322 - accuracy: 0.7652 - val_loss: 0.5696 - val_accuracy: 0.7973
# Epoch 251/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6328 - accuracy: 0.7534 - val_loss: 0.5735 - val_accuracy: 0.8311
# Epoch 252/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6274 - accuracy: 0.7568 - val_loss: 0.5678 - val_accuracy: 0.8176
# Epoch 253/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6949 - accuracy: 0.7230 - val_loss: 0.5742 - val_accuracy: 0.8176
# Epoch 254/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6273 - accuracy: 0.7652 - val_loss: 0.5731 - val_accuracy: 0.7905
# Epoch 255/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6059 - accuracy: 0.7753 - val_loss: 0.5615 - val_accuracy: 0.8108
# Epoch 256/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6752 - accuracy: 0.7483 - val_loss: 0.5714 - val_accuracy: 0.8176
# Epoch 257/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6354 - accuracy: 0.7551 - val_loss: 0.5580 - val_accuracy: 0.8311
# Epoch 258/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6009 - accuracy: 0.7787 - val_loss: 0.5331 - val_accuracy: 0.8243
# Epoch 259/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6713 - accuracy: 0.7669 - val_loss: 0.5633 - val_accuracy: 0.8041
# Epoch 260/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6345 - accuracy: 0.7517 - val_loss: 0.5486 - val_accuracy: 0.8108
# Epoch 261/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6064 - accuracy: 0.7618 - val_loss: 0.5625 - val_accuracy: 0.7838
# Epoch 262/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6306 - accuracy: 0.7736 - val_loss: 0.5924 - val_accuracy: 0.7838
# Epoch 263/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.5863 - accuracy: 0.8007 - val_loss: 0.5605 - val_accuracy: 0.7770
# Epoch 264/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6480 - accuracy: 0.7686 - val_loss: 0.5431 - val_accuracy: 0.7838
# Epoch 265/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.
500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.5930 - accuracy: 0.7534 - val_loss: 0.5532 - val_accuracy: 0.8108
# Epoch 297/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6397 - accuracy: 0.7314 - val_loss: 0.5590 - val_accuracy: 0.7770
# Epoch 298/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6202 - accuracy: 0.7720 - val_loss: 0.5377 - val_accuracy: 0.7905
# Epoch 299/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.5926 - accuracy: 0.7821 - val_loss: 0.5325 - val_accuracy: 0.8108
# Epoch 300/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6142 - accuracy: 0.7534 - val_loss: 0.5362 - val_accuracy: 0.7905
# Epoch 301/500
# 74/74 [==============================] - 1s 7ms/step - loss: 0.5962 - accuracy: 0.7720 - val_loss: 0.5381 - val_accuracy: 0.8041
# Epoch 302/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6480 - accuracy: 0.7280 - val_loss: 0.5577 - val_accuracy: 0.7905
# Epoch 303/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6520 - accuracy: 0.7280 - val_loss: 0.5427 - val_accuracy: 0.8176
# Epoch 304/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6117 - accuracy: 0.7669 - val_loss: 0.5480 - val_accuracy: 0.8041
# Epoch 305/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6261 - accuracy: 0.7517 - val_loss: 0.5501 - val_accuracy: 0.8041
# Epoch 306/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.5990 - accuracy: 0.7601 - val_loss: 0.5606 - val_accuracy: 0.8243
# Epoch 307/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6356 - accuracy: 0.7517 - val_loss: 0.5700 - val_accuracy: 0.7905
# Epoch 308/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6469 - accuracy: 0.7399 - val_loss: 0.5453 - val_accuracy: 0.7838
# Epoch 309/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6325 - accuracy: 0.7416 - val_loss: 0.5350 - val_accuracy: 0.8176
# Epoch 310/500
# 74/74 [==============================] - 1s 7ms/step - loss: 0.6461 - accuracy: 0.7162 - val_loss: 0.5547 - val_accuracy: 0.8243
# Epoch 311/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6292 - accuracy: 0.7517 - val_loss: 0.5377 - val_accuracy: 0.8041
# Epoch 312/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6112 - accuracy: 0.7416 - val_loss: 0.5364 - val_accuracy: 0.8108
# Epoch 313/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.5983 - accuracy: 0.7787 - val_loss: 0.5295 - val_accuracy: 0.8041
# Epoch 314/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6054 - accuracy: 0.7601 - val_loss: 0.5413 - val_accuracy: 0.7973
# Epoch 315/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6146 - accuracy: 0.7804 - val_loss: 0.5455 - val_accuracy: 0.8176
# Epoch 316/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6002 - accuracy: 0.7635 - val_loss: 0.5551 - val_accuracy: 0.8041
# Epoch 317/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.5783 - accuracy: 0.7753 - val_loss: 0.5414 - val_accuracy: 0.7973
# Epoch 318/500
# 74/74 [==============================] - 1s 7ms/step - loss: 0.6133 - accuracy: 0.7889 - val_loss: 0.5561 - val_accuracy: 0.7973
# Epoch 319/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.5969 - accuracy: 0.7855 - val_loss: 0.5671 - val_accuracy: 0.7973
# Epoch 320/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6137 - accuracy: 0.7466 - val_loss: 0.5417 - val_accuracy: 0.8041
# Epoch 321/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6046 - accuracy: 0.7686 - val_loss: 0.5421 - val_accuracy: 0.7905
# Epoch 322/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.5918 - accuracy: 0.7584 - val_loss: 0.5269 - val_accuracy: 0.8041
# Epoch 323/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.5811 - accuracy: 0.7500 - val_loss: 0.5474 - val_accuracy: 0.8041
# Epoch 324/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.5730 - accuracy: 0.7905 - val_loss: 0.5501 - val_accuracy: 0.8176
# Epoch 325/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6385 - accuracy: 0.7601 - val_loss: 0.5487 - val_accuracy: 0.8176
# Epoch 326/500
# 74/74 [==============================] - 1s 7ms/step - loss: 0.
500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.5985 - accuracy: 0.7652 - val_loss: 0.4622 - val_accuracy: 0.8378
# Epoch 444/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6015 - accuracy: 0.7483 - val_loss: 0.4575 - val_accuracy: 0.8446
# Epoch 445/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6260 - accuracy: 0.7399 - val_loss: 0.4582 - val_accuracy: 0.8649
# Epoch 446/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6369 - accuracy: 0.7517 - val_loss: 0.4773 - val_accuracy: 0.8378
# Epoch 447/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6146 - accuracy: 0.7314 - val_loss: 0.4600 - val_accuracy: 0.8378
# Epoch 448/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6171 - accuracy: 0.7686 - val_loss: 0.4697 - val_accuracy: 0.8446
# Epoch 449/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.5932 - accuracy: 0.7568 - val_loss: 0.4547 - val_accuracy: 0.8581
# Epoch 450/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6134 - accuracy: 0.7230 - val_loss: 0.4601 - val_accuracy: 0.8243
# Epoch 451/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6147 - accuracy: 0.7196 - val_loss: 0.4764 - val_accuracy: 0.8311
# Epoch 452/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6213 - accuracy: 0.7432 - val_loss: 0.4967 - val_accuracy: 0.8378
# Epoch 453/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6567 - accuracy: 0.7162 - val_loss: 0.4986 - val_accuracy: 0.8378
# Epoch 454/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6044 - accuracy: 0.7500 - val_loss: 0.4786 - val_accuracy: 0.8243
# Epoch 455/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.5998 - accuracy: 0.7517 - val_loss: 0.4379 - val_accuracy: 0.8446
# Epoch 456/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6203 - accuracy: 0.7365 - val_loss: 0.4754 - val_accuracy: 0.8514
# Epoch 457/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6204 - accuracy: 0.7432 - val_loss: 0.4716 - val_accuracy: 0.8514
# Epoch 458/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6146 - accuracy: 0.7179 - val_loss: 0.4450 - val_accuracy: 0.8311
# Epoch 459/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.5708 - accuracy: 0.7601 - val_loss: 0.4248 - val_accuracy: 0.8446
# Epoch 460/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6115 - accuracy: 0.7348 - val_loss: 0.4459 - val_accuracy: 0.8176
# Epoch 461/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.5837 - accuracy: 0.7703 - val_loss: 0.4447 - val_accuracy: 0.8243
# Epoch 462/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6168 - accuracy: 0.7382 - val_loss: 0.4398 - val_accuracy: 0.8649
# Epoch 463/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6137 - accuracy: 0.7314 - val_loss: 0.4500 - val_accuracy: 0.8784
# Epoch 464/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.5982 - accuracy: 0.7568 - val_loss: 0.4525 - val_accuracy: 0.8649
# Epoch 465/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6243 - accuracy: 0.7264 - val_loss: 0.4707 - val_accuracy: 0.8311
# Epoch 466/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.5803 - accuracy: 0.7770 - val_loss: 0.4592 - val_accuracy: 0.8446
# Epoch 467/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6172 - accuracy: 0.7399 - val_loss: 0.4823 - val_accuracy: 0.8581
# Epoch 468/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6075 - accuracy: 0.7534 - val_loss: 0.4566 - val_accuracy: 0.8514
# Epoch 469/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6566 - accuracy: 0.7213 - val_loss: 0.4992 - val_accuracy: 0.8784
# Epoch 470/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6346 - accuracy: 0.7399 - val_loss: 0.4947 - val_accuracy: 0.8649
# Epoch 471/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.5734 - accuracy: 0.7736 - val_loss: 0.4479 - val_accuracy: 0.8649
# Epoch 472/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6653 - accuracy: 0.7179 - val_loss: 0.4947 - val_accuracy: 0.8311
# Epoch 473/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6288 - accuracy: 0.7618 - val_loss: 0.4745 - val_accuracy: 0.8378
# Epoch 474/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6104 - accuracy: 0.7466 - val_loss: 0.4630 - val_accuracy: 0.8581
# Epoch 475/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.5929 - accuracy: 0.7770 - val_loss: 0.4584 - val_accuracy: 0.8581
# Epoch 476/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6080 - accuracy: 0.7449 - val_loss: 0.4493 - val_accuracy: 0.8446
# Epoch 477/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6366 - accuracy: 0.7264 - val_loss: 0.4949 - val_accuracy: 0.8514
# Epoch 478/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6093 - accuracy: 0.7449 - val_loss: 0.4607 - val_accuracy: 0.8581
# Epoch 479/500
# 74/74 [==============================] - 1s 7ms/step - loss: 0.6112 - accuracy: 0.7416 - val_loss: 0.4633 - val_accuracy: 0.8378
# Epoch 480/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.5984 - accuracy: 0.7500 - val_loss: 0.4583 - val_accuracy: 0.8446
# Epoch 481/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6055 - accuracy: 0.7855 - val_loss: 0.4575 - val_accuracy: 0.8378
# Epoch 482/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6009 - accuracy: 0.7466 - val_loss: 0.4654 - val_accuracy: 0.8378
# Epoch 483/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.5755 - accuracy: 0.7534 - val_loss: 0.4559 - val_accuracy: 0.8378
# Epoch 484/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.5863 - accuracy: 0.7449 - val_loss: 0.4578 - val_accuracy: 0.8311
# Epoch 485/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6171 - accuracy: 0.7466 - val_loss: 0.4560 - val_accuracy: 0.8243
# Epoch 486/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.5792 - accuracy: 0.7720 - val_loss: 0.4117 - val_accuracy: 0.8378
# Epoch 487/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6324 - accuracy: 0.7483 - val_loss: 0.4848 - val_accuracy: 0.8581
# Epoch 488/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6070 - accuracy: 0.7568 - val_loss: 0.4418 - val_accuracy: 0.8649
# Epoch 489/500
# 74/74 [==============================] - 1s 7ms/step - loss: 0.6065 - accuracy: 0.7416 - val_loss: 0.4548 - val_accuracy: 0.8514
# Epoch 490/500
# 74/74 [==============================] - 1s 7ms/step - loss: 0.5699 - accuracy: 0.7686 - val_loss: 0.4570 - val_accuracy: 0.8378
# Epoch 491/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6090 - accuracy: 0.7449 - val_loss: 0.4646 - val_accuracy: 0.8581
# Epoch 492/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6212 - accuracy: 0.7348 - val_loss: 0.4856 - val_accuracy: 0.8446
# Epoch 493/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.5671 - accuracy: 0.7753 - val_loss: 0.4557 - val_accuracy: 0.8378
# Epoch 494/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.5977 - accuracy: 0.7534 - val_loss: 0.4414 - val_accuracy: 0.8446
# Epoch 495/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.6067 - accuracy: 0.7500 - val_loss: 0.4687 - val_accuracy: 0.8851
# Epoch 496/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.6502 - accuracy: 0.7230 - val_loss: 0.4799 - val_accuracy: 0.8514
# Epoch 497/500
# 74/74 [==============================] - 1s 7ms/step - loss: 0.5959 - accuracy: 0.7652 - val_loss: 0.4391 - val_accuracy: 0.8514
# Epoch 498/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.5971 - accuracy: 0.7635 - val_loss: 0.4588 - val_accuracy: 0.8716
# Epoch 499/500
# 74/74 [==============================] - 0s 6ms/step - loss: 0.5710 - accuracy: 0.7804 - val_loss: 0.4403 - val_accuracy: 0.8581
# Epoch 500/500
# 74/74 [==============================] - 0s 7ms/step - loss: 0.5960 - accuracy: 0.7635 - val_loss: 0.4671 - val_accuracy: 0.8311
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4671 - accuracy: 0.8311
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:62: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# [0.8108108043670654, 0.837837815284729, 0.8310810923576355, 0.837837815284729, 0.8310810923576355]
# Accuracy: 0.83
# Sensitivity: 0.8691
# Specificity: 0.7875
# MCC: 0.6580
# Precision: 0.8076
