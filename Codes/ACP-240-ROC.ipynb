# %% [markdown]
# <a href="https://colab.research.google.com/github/mrzResearchArena/Anticancer-Peptides-CNN/blob/master/ACP-240-ROC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### [1]. Google Drive Initialization:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd 'drive/My Drive/ACP-PyFeat'
# Out:
# /content/drive/My Drive/ACP-PyFeat

# %%
ls
# Out:
# bits-164.npy    blosum-500.npy  model-240.png      PyFeat-500-20.npy
# bits-240.npy    blosum-740.npy  model-740.png      PyFeat-500.npy
# bits-500.npy    bpf-164.npy     PyFeat-164-20.npy  PyFeat-740-20.npy
# bits-740.npy    bpf-240.npy     PyFeat-164.npy     PyFeat-740.npy
# blosum-164.npy  bpf-500.npy     PyFeat-240-20.npy  ROC.png
# blosum-240.npy  bpf-740.npy     PyFeat-240.npy

# %% [markdown]
# ### [2]. Load Deep Learning API (Keras):

# %%
# # Initialize TF-2.x:
# try:
#     %tensorflow_version 2.x  # Colab only.
# except Exception:
#     pass

# import tensorflow as tf
# print('We\'re using TF-{}.'.format(tf.__version__))

# # Colab Auto Click: [https://paste.ubuntu.com/p/R78fGBJbjb/]

# %%
# Deep Neural Networks:
import tensorflow as tf; print('We\'re using TF-{}.'.format(tf.__version__))
# import keras; print('We\'re using Keras-{}.'.format(keras.__version__))
from tensorflow.keras.layers import (Input, Dense, Dropout, Flatten, BatchNormalization,
                                     Conv1D, Conv2D, MaxPooling1D, MaxPooling2D,
                                     LSTM, GRU, Embedding, Bidirectional, Concatenate)
from tensorflow.keras.regularizers import (l1, l2, l1_l2)
from tensorflow.keras.optimizers import (RMSprop, Adam, SGD)
from tensorflow.keras.models import (Sequential, Model)

# Core:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import interp
import matplotlib.patches as patches

# Performance:
from sklearn.metrics import (confusion_matrix, classification_report, matthews_corrcoef, precision_score, roc_curve, auc)
from sklearn.model_selection import (StratifiedKFold, KFold, train_test_split)

#Utilities:
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import to_categorical as labelEncoding   # Usages: Y = labelEncoding(Y, dtype=int)
from tensorflow.keras.utils import plot_model                        # Usages: plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=False, expand_nested=True)

#end-import
# Out:
# We're using TF-2.3.0.

# %%
def lossPlot(results):
    plt.title(label='Loss: Training and Validation')
    plt.plot(results.history['loss'], label='Training Loss')
    plt.plot(results.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
#end-def

def accuracyPlot(results):
    plt.title(label='Accuracy: Training and Validation')
    plt.plot(results.history['accuracy'], label='Training Accuracy')
    plt.plot(results.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()
#end-def

# %%
def rocPlot(TPR, meanFPR):
    plt.plot([0,1], [0,1],linestyle = '--',lw = 2,color = 'black')
    meanTPR = np.mean(TPR, axis=0)
    meanAUC = auc(meanFPR, meanTPR)
    plt.plot(meanFPR, meanTPR, color='blue',
            label=r'Mean ROC (AUC = %0.2f )' % (meanAUC),lw=2, alpha=1)

    plt.xlabel('False Positive Rate (FPR)')
    plt.ylabel('True Positive Rate (TPR)')
    plt.title('Receiver Operating Characteristic Curve (ROC Curve)')
    plt.legend(loc="lower right")
    plt.savefig('ROC-240.png')
    plt.show()
#end-def

# %% [markdown]
# ### [3]. Load Datasets:

# %%
T = 15 # terminus_length

X1 = np.load('bpf-240.npy')
X2 = np.load('bits-240.npy')
X3 = np.load('blosum-240.npy')

X1 = X1[:,0:T,:]
X2 = X2[:,0:T,:]
X3 = X3[:,0:T,:]

Y  = [1 for _ in range(129)]
Y += [0 for _ in range(111)]
Y = labelEncoding(Y, dtype=int)


print(X1.shape)
print(X2.shape)
print(X3.shape)
print(Y.shape)
# Out:
# (240, 15, 20)
# (240, 15, 31)
# (240, 15, 20)
# (240, 2)

# %% [markdown]
# ### [4]. Generate Model:

# %%
# Model-240

def Network():
    ### Head-1:
    input1 = Input(shape=X1[0].shape)

    x = Conv1D(filters=10, kernel_size=4, padding='same', activation='relu', kernel_regularizer=l2(l=0.01))(input1)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.80)(x)

    x = Conv1D(filters=8, kernel_size=3, padding='same', activation='relu', kernel_regularizer=l2(l=0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.70)(x)

    head1 = Flatten()(x)


    ### Head-2:
    input2 = Input(shape=X2[0].shape)

    x = Conv1D(filters=10, kernel_size=4, padding='same', activation='relu', kernel_regularizer=l2(l=0.01))(input2)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.80)(x)

    x = Conv1D(filters=8, kernel_size=3, padding='same', activation='relu', kernel_regularizer=l2(l=0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.70)(x)

    head2 = Flatten()(x)


    ### Head-3:
    input3 = Input(shape=X3[0].shape)
    
    x = Conv1D(filters=10, kernel_size=4, padding='same', activation='relu',)(input3)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.80)(x)

    x = Conv1D(filters=8, kernel_size=3, padding='same', activation='relu', kernel_regularizer=l2(l=0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.70)(x)

    head3 = Flatten()(x)


    # merge
    # merge = concatenate(inputs=[head1, head2, head3])
    merge = Concatenate()([head1, head2, head3])

    output = Dense(units=8, activation='relu', kernel_regularizer=l2(l=0.01))(merge)
    output = BatchNormalization()(output)
    output = Dropout(rate=0.80)(output)

    output = Dense(units=2, activation='softmax')(output)

    return Model(inputs=[input1, input2, input3], outputs=[output])
#end-def

# %%
model = Network()
model.summary()
plot_model(model, to_file='model-240.png', show_shapes=True, show_layer_names=False, expand_nested=True)
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 15, 20)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 15, 31)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 15, 20)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 15, 10)       810         input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 15, 10)       1250        input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 15, 10)       810         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 15, 10)       40          conv1d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 15, 10)       40          conv1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 15, 10)       40          conv1d_4[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 15, 10)       0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 15, 10)       0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 15, 10)       0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 15, 8)        248         dropout[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 15, 8)        248         dropout_2[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 15, 8)        248         dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 15, 8)        32          conv1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 15, 8)        32          conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 15, 8)        32          conv1d_5[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 15, 8)        0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 15, 8)        0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 15, 8)        0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 120)          0           dropout_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 120)          0           dropout_3[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 120)          0           dropout_5[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 360)          0           flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 8)            2888        concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8)            32          dense[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 8)            0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            18          dropout_6[0][0]
# ==================================================================================================
# Total params: 6,768
# Trainable params: 6,644
# Non-trainable params: 124
# __________________________________________________________________________________________________

# %% [markdown]
# ### [5]. Run Model:

# %%
setEpochNumber     = 500     # Performed-welled in epoch 600.
setBatchSizeNumber = 8
####################################################

cv = KFold(n_splits=5, shuffle=True, random_state=101)

Accuracy = []
Sensitivity = []
Specificity = []
Precision = []
MCC = []

# ROC Curve:
fig1 = plt.figure(figsize=[12,12])

TPR = []
meanFPR = np.linspace(0, 1, 100)

i = 1

for train, test in cv.split(Y):

    # Compile Model:
    model = Network()
    model.compile(optimizer=Adam(learning_rate=0.005),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    # Run Model:
    results = model.fit(x=[X1[train,:,:], X2[train,:,:], X3[train,:,:]],
                        y=Y[train,:],
                        validation_data=([X1[test,:,:], X2[test,:,:], X3[test,:,:],], Y[test,:]),
                        batch_size=setBatchSizeNumber, epochs=setEpochNumber,
                        verbose=1,
                        callbacks=[])
    
    accuracy = model.evaluate(x=[X1[test,:,:], X2[test,:,:], X3[test,:,:]], y=Y[test,:], batch_size=setBatchSizeNumber)
    Accuracy.append(accuracy[1])

    # Performance Metices:
    Yactual = Y[test,:].argmax(axis=1)
    Yp = model.predict([X1[test,:,:], X2[test,:,:], X3[test,:,:]])
    v = Yp
    Yp = Yp.argmax(axis=1)

    CM = confusion_matrix(y_pred=Yp, y_true=Yactual)
    TN, FP, FN, TP = CM.ravel()

    MCC.append(matthews_corrcoef(y_true=Yactual, y_pred=Yp))
    Sensitivity.append( TP / (TP + FN) )
    Specificity.append( TN / (TN + FP) )
    Precision.append(precision_score(y_true=Yactual, y_pred=Yp))
    
    # ROC Curve
    fpr, tpr, _ = roc_curve(Yactual, v[:,1])
    TPR.append(interp(meanFPR, fpr, tpr))
    rocauc = auc(fpr, tpr)
    plt.plot(fpr, tpr, lw=2, alpha=0.3, label='ROC fold %d (AUC = %0.2f)' % (i, rocauc))
    i= i+1
    
    # # Performance Plot
    # print('#################################################')
    # print('Fold\'s Accuracy: {:.2f}'.format(accuracy[1]*100.0))
    # lossPlot(results)
    # accuracyPlot(results)
    # print('#################################################')

    
#end-for

rocPlot(TPR, meanFPR)

print('Accuracy [Each Fold]: {}'.format(Accuracy))
print('Accuracy: {:.2f}'.format(np.sum(Accuracy)/5.0))
print('Sensitivity: {0:.4f}'.format(np.sum(Sensitivity)/5.00))
print('Specificity: {0:.4f}'.format(np.sum(Specificity)/5.00))
print('MCC: {0:.4f}'.format(np.sum(MCC)/5.00))
print('Precision: {0:.4f}'.format(np.sum(Precision)/5.00))
# Out:
# Epoch 1/500
# 24/24 [==============================] - 0s 19ms/step - loss: 1.6404 - accuracy: 0.5000 - val_loss: 1.3551 - val_accuracy: 0.5417
# Epoch 2/500
# 24/24 [==============================] - 0s 4ms/step - loss: 1.6409 - accuracy: 0.4792 - val_loss: 1.3436 - val_accuracy: 0.5417
# Epoch 3/500
# 24/24 [==============================] - 0s 4ms/step - loss: 1.4813 - accuracy: 0.5312 - val_loss: 1.3229 - val_accuracy: 0.4792
# Epoch 4/500
# 24/24 [==============================] - 0s 4ms/step - loss: 1.3313 - accuracy: 0.5104 - val_loss: 1.3000 - val_accuracy: 0.4583
# Epoch 5/500
# 24/24 [==============================] - 0s 4ms/step - loss: 1.2845 - accuracy: 0.5521 - val_loss: 1.2702 - val_accuracy: 0.4583
# Epoch 6/500
# 24/24 [==============================] - 0s 4ms/step - loss: 1.2374 - accuracy: 0.5573 - val_loss: 1.2321 - val_accuracy: 0.4583
# Epoch 7/500
# 24/24 [==============================] - 0s 4ms/step - loss: 1.2005 - accuracy: 0.5260 - val_loss: 1.1989 - val_accuracy: 0.4583
# Epoch 8/500
# 24/24 [==============================] - 0s 4ms/step - loss: 1.1511 - accuracy: 0.5677 - val_loss: 1.1611 - val_accuracy: 0.4583
# Epoch 9/500
# 24/24 [==============================] - 0s 4ms/step - loss: 1.1116 - accuracy: 0.5625 - val_loss: 1.1299 - val_accuracy: 0.4583
# Epoch 10/500
# 24/24 [==============================] - 0s 4ms/step - loss: 1.0917 - accuracy: 0.5521 - val_loss: 1.1022 - val_accuracy: 0.4583
# Epoch 11/500
# 24/24 [==============================] - 0s 4ms/step - loss: 1.0843 - accuracy: 0.5208 - val_loss: 1.0725 - val_accuracy: 0.4583
# Epoch 12/500
# 24/24 [==============================] - 0s 5ms/step - loss: 1.0437 - accuracy: 0.5469 - val_loss: 1.0394 - val_accuracy: 0.4583
# Epoch 13/500
# 24/24 [==============================] - 0s 4ms/step - loss: 1.0118 - accuracy: 0.5469 - val_loss: 1.0160 - val_accuracy: 0.4583
# Epoch 14/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.9810 - accuracy: 0.5469 - val_loss: 0.9981 - val_accuracy: 0.4583
# Epoch 15/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.9518 - accuracy: 0.5521 - val_loss: 0.9852 - val_accuracy: 0.4583
# Epoch 16/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.9553 - accuracy: 0.5052 - val_loss: 0.9624 - val_accuracy: 0.4583
# Epoch 17/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.
500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7174 - accuracy: 0.6927 - val_loss: 0.7090 - val_accuracy: 0.7708
# Epoch 201/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7948 - accuracy: 0.6615 - val_loss: 0.7271 - val_accuracy: 0.7292
# Epoch 202/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7739 - accuracy: 0.6771 - val_loss: 0.7026 - val_accuracy: 0.7708
# Epoch 203/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7131 - accuracy: 0.7344 - val_loss: 0.6992 - val_accuracy: 0.7708
# Epoch 204/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7698 - accuracy: 0.6719 - val_loss: 0.6906 - val_accuracy: 0.7708
# Epoch 205/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7235 - accuracy: 0.7031 - val_loss: 0.6764 - val_accuracy: 0.7500
# Epoch 206/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7505 - accuracy: 0.7240 - val_loss: 0.7054 - val_accuracy: 0.7500
# Epoch 207/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7519 - accuracy: 0.7240 - val_loss: 0.7050 - val_accuracy: 0.7292
# Epoch 208/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7532 - accuracy: 0.6719 - val_loss: 0.6965 - val_accuracy: 0.7083
# Epoch 209/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7554 - accuracy: 0.6979 - val_loss: 0.6876 - val_accuracy: 0.7083
# Epoch 210/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7370 - accuracy: 0.7031 - val_loss: 0.7025 - val_accuracy: 0.7292
# Epoch 211/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7598 - accuracy: 0.7240 - val_loss: 0.6840 - val_accuracy: 0.6875
# Epoch 212/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7535 - accuracy: 0.7188 - val_loss: 0.7053 - val_accuracy: 0.7708
# Epoch 213/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7665 - accuracy: 0.6823 - val_loss: 0.7263 - val_accuracy: 0.7708
# Epoch 214/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7836 - accuracy: 0.6875 - val_loss: 0.7319 - val_accuracy: 0.7083
# Epoch 215/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7770 - accuracy: 0.6979 - val_loss: 0.7054 - val_accuracy: 0.7083
# Epoch 216/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7543 - accuracy: 0.7448 - val_loss: 0.6945 - val_accuracy: 0.7500
# Epoch 217/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7859 - accuracy: 0.6927 - val_loss: 0.7227 - val_accuracy: 0.7292
# Epoch 218/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7260 - accuracy: 0.6927 - val_loss: 0.7135 - val_accuracy: 0.7292
# Epoch 219/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.8397 - accuracy: 0.6458 - val_loss: 0.7333 - val_accuracy: 0.7500
# Epoch 220/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.8024 - accuracy: 0.7135 - val_loss: 0.7394 - val_accuracy: 0.7292
# Epoch 221/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.8203 - accuracy: 0.6458 - val_loss: 0.7302 - val_accuracy: 0.7292
# Epoch 222/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7495 - accuracy: 0.7083 - val_loss: 0.7182 - val_accuracy: 0.7500
# Epoch 223/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7647 - accuracy: 0.7083 - val_loss: 0.7015 - val_accuracy: 0.7917
# Epoch 224/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6987 - accuracy: 0.7188 - val_loss: 0.6987 - val_accuracy: 0.7708
# Epoch 225/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7445 - accuracy: 0.7396 - val_loss: 0.6941 - val_accuracy: 0.7917
# Epoch 226/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6915 - accuracy: 0.7708 - val_loss: 0.6910 - val_accuracy: 0.7917
# Epoch 227/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7654 - accuracy: 0.6927 - val_loss: 0.6990 - val_accuracy: 0.7917
# Epoch 228/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7749 - accuracy: 0.6823 - val_loss: 0.7183 - val_accuracy: 0.7500
# Epoch 229/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7895 - accuracy: 0.7031 - val_loss: 0.7305 - val_accuracy: 0.7083
# Epoch 230/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7362 - accuracy: 0.7344 - val_loss: 0.7359 - val_accuracy: 0.7292
# Epoch 231/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.8205 - accuracy: 0.6667 - val_loss: 0.7273 - val_accuracy: 0.7500
# Epoch 232/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7681 - accuracy: 0.7396 - val_loss: 0.7158 - val_accuracy: 0.7917
# Epoch 233/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.8006 - accuracy: 0.6927 - val_loss: 0.6998 - val_accuracy: 0.7708
# Epoch 234/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7094 - accuracy: 0.7448 - val_loss: 0.6754 - val_accuracy: 0.7917
# Epoch 235/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7996 - accuracy: 0.6667 - val_loss: 0.6802 - val_accuracy: 0.8125
# Epoch 236/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7237 - accuracy: 0.7292 - val_loss: 0.6780 - val_accuracy: 0.7917
# Epoch 237/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.8070 - accuracy: 0.7031 - val_loss: 0.7178 - val_accuracy: 0.7500
# Epoch 238/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7537 - accuracy: 0.7188 - val_loss: 0.7210 - val_accuracy: 0.7500
# Epoch 239/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6989 - accuracy: 0.7604 - val_loss: 0.6955 - val_accuracy: 0.7500
# Epoch 240/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7290 - accuracy: 0.7188 - val_loss: 0.6876 - val_accuracy: 0.7500
# Epoch 241/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7325 - accuracy: 0.7135 - val_loss: 0.6998 - val_accuracy: 0.7500
# Epoch 242/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6934 - accuracy: 0.7396 - val_loss: 0.6759 - val_accuracy: 0.7500
# Epoch 243/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7391 - accuracy: 0.7604 - val_loss: 0.7029 - val_accuracy: 0.7500
# Epoch 244/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7062 - accuracy: 0.7292 - val_loss: 0.7017 - val_accuracy: 0.7083
# Epoch 245/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7287 - accuracy: 0.7604 - val_loss: 0.6915 - val_accuracy: 0.7292
# Epoch 246/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7913 - accuracy: 0.6823 - val_loss: 0.7185 - val_accuracy: 0.7083
# Epoch 247/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7644 - accuracy: 0.6927 - val_loss: 0.7167 - val_accuracy: 0.7500
# Epoch 248/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7852 - accuracy: 0.6719 - val_loss: 0.7007 - val_accuracy: 0.7500
# Epoch 249/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7429 - accuracy: 0.7552 - val_loss: 0.7024 - val_accuracy: 0.7292
# Epoch 250/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7321 - accuracy: 0.7240 - val_loss: 0.6881 - val_accuracy: 0.7292
# Epoch 251/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7257 - accuracy: 0.7031 - val_loss: 0.6758 - val_accuracy: 0.7708
# Epoch 252/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7587 - accuracy: 0.7083 - val_loss: 0.6644 - val_accuracy: 0.8542
# Epoch 253/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7280 - accuracy: 0.6823 - val_loss: 0.6499 - val_accuracy: 0.7917
# Epoch 254/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6959 - accuracy: 0.7344 - val_loss: 0.6481 - val_accuracy: 0.8125
# Epoch 255/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6845 - accuracy: 0.7604 - val_loss: 0.6439 - val_accuracy: 0.8333
# Epoch 256/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7302 - accuracy: 0.7240 - val_loss: 0.6462 - val_accuracy: 0.7917
# Epoch 257/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7048 - accuracy: 0.7760 - val_loss: 0.6319 - val_accuracy: 0.7708
# Epoch 258/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7762 - accuracy: 0.6927 - val_loss: 0.6667 - val_accuracy: 0.7292
# Epoch 259/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7901 - accuracy: 0.7083 - val_loss: 0.6774 - val_accuracy: 0.7708
# Epoch 260/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7548 - accuracy: 0.7552 - val_loss: 0.6767 - val_accuracy: 0.7500
# Epoch 261/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.
500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7004 - accuracy: 0.7917 - val_loss: 0.6292 - val_accuracy: 0.7500
# Epoch 293/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7604 - accuracy: 0.7292 - val_loss: 0.6467 - val_accuracy: 0.7917
# Epoch 294/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7742 - accuracy: 0.6719 - val_loss: 0.6646 - val_accuracy: 0.7708
# Epoch 295/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7931 - accuracy: 0.6771 - val_loss: 0.6684 - val_accuracy: 0.7708
# Epoch 296/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7356 - accuracy: 0.7604 - val_loss: 0.6597 - val_accuracy: 0.7500
# Epoch 297/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7362 - accuracy: 0.7552 - val_loss: 0.6467 - val_accuracy: 0.8333
# Epoch 298/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7544 - accuracy: 0.7240 - val_loss: 0.6497 - val_accuracy: 0.7917
# Epoch 299/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7324 - accuracy: 0.7135 - val_loss: 0.6542 - val_accuracy: 0.7292
# Epoch 300/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7691 - accuracy: 0.6875 - val_loss: 0.6716 - val_accuracy: 0.7708
# Epoch 301/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7118 - accuracy: 0.7500 - val_loss: 0.6443 - val_accuracy: 0.7708
# Epoch 302/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6999 - accuracy: 0.7604 - val_loss: 0.6278 - val_accuracy: 0.7708
# Epoch 303/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7735 - accuracy: 0.6927 - val_loss: 0.6378 - val_accuracy: 0.7917
# Epoch 304/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7901 - accuracy: 0.6771 - val_loss: 0.6677 - val_accuracy: 0.7292
# Epoch 305/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7413 - accuracy: 0.6823 - val_loss: 0.6604 - val_accuracy: 0.7292
# Epoch 306/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7587 - accuracy: 0.7188 - val_loss: 0.6555 - val_accuracy: 0.7292
# Epoch 307/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7736 - accuracy: 0.7083 - val_loss: 0.6546 - val_accuracy: 0.7500
# Epoch 308/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7496 - accuracy: 0.7135 - val_loss: 0.6640 - val_accuracy: 0.7917
# Epoch 309/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7205 - accuracy: 0.7396 - val_loss: 0.6350 - val_accuracy: 0.8333
# Epoch 310/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6962 - accuracy: 0.7396 - val_loss: 0.6166 - val_accuracy: 0.8125
# Epoch 311/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7354 - accuracy: 0.7031 - val_loss: 0.6434 - val_accuracy: 0.7708
# Epoch 312/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7137 - accuracy: 0.7031 - val_loss: 0.6471 - val_accuracy: 0.7917
# Epoch 313/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7872 - accuracy: 0.6719 - val_loss: 0.6481 - val_accuracy: 0.7708
# Epoch 314/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7188 - accuracy: 0.7500 - val_loss: 0.6444 - val_accuracy: 0.7917
# Epoch 315/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7323 - accuracy: 0.6979 - val_loss: 0.6454 - val_accuracy: 0.7917
# Epoch 316/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7389 - accuracy: 0.6771 - val_loss: 0.6469 - val_accuracy: 0.7917
# Epoch 317/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7493 - accuracy: 0.7396 - val_loss: 0.6576 - val_accuracy: 0.7917
# Epoch 318/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7323 - accuracy: 0.7344 - val_loss: 0.6611 - val_accuracy: 0.8125
# Epoch 319/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7874 - accuracy: 0.6615 - val_loss: 0.6591 - val_accuracy: 0.7500
# Epoch 320/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7613 - accuracy: 0.7083 - val_loss: 0.6468 - val_accuracy: 0.7708
# Epoch 321/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7294 - accuracy: 0.7135 - val_loss: 0.6467 - val_accuracy: 0.8125
# Epoch 322/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7192 - accuracy: 0.7500 - val_loss: 0.6288 - val_accuracy: 0.8125
# Epoch 323/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7264 - accuracy: 0.7031 - val_loss: 0.6489 - val_accuracy: 0.7917
# Epoch 324/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7659 - accuracy: 0.6667 - val_loss: 0.6553 - val_accuracy: 0.7708
# Epoch 325/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7603 - accuracy: 0.6823 - val_loss: 0.6437 - val_accuracy: 0.7917
# Epoch 326/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7558 - accuracy: 0.7604 - val_loss: 0.6490 - val_accuracy: 0.8125
# Epoch 327/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7298 - accuracy: 0.7083 - val_loss: 0.6457 - val_accuracy: 0.8333
# Epoch 328/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7126 - accuracy: 0.7292 - val_loss: 0.6443 - val_accuracy: 0.7917
# Epoch 329/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7794 - accuracy: 0.6875 - val_loss: 0.6701 - val_accuracy: 0.7708
# Epoch 330/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7563 - accuracy: 0.6979 - val_loss: 0.6870 - val_accuracy: 0.7500
# Epoch 331/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7213 - accuracy: 0.7240 - val_loss: 0.6507 - val_accuracy: 0.7917
# Epoch 332/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7163 - accuracy: 0.7188 - val_loss: 0.6332 - val_accuracy: 0.7917
# Epoch 333/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7182 - accuracy: 0.7240 - val_loss: 0.6363 - val_accuracy: 0.7708
# Epoch 334/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7712 - accuracy: 0.7083 - val_loss: 0.6668 - val_accuracy: 0.8125
# Epoch 335/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7263 - accuracy: 0.7240 - val_loss: 0.6522 - val_accuracy: 0.8125
# Epoch 336/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7379 - accuracy: 0.7292 - val_loss: 0.6472 - val_accuracy: 0.8333
# Epoch 337/500
# ...
# Epoch 398/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6996 - accuracy: 0.7292 - val_loss: 0.6559 - val_accuracy: 0.8125
# Epoch 399/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7000 - accuracy: 0.7188 - val_loss: 0.6224 - val_accuracy: 0.8333
# Epoch 400/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6937 - accuracy: 0.7135 - val_loss: 0.6070 - val_accuracy: 0.8333
# Epoch 401/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7493 - accuracy: 0.7031 - val_loss: 0.6784 - val_accuracy: 0.7500
# Epoch 402/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7254 - accuracy: 0.7240 - val_loss: 0.6636 - val_accuracy: 0.8125
# Epoch 403/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7583 - accuracy: 0.6875 - val_loss: 0.6662 - val_accuracy: 0.8125
# Epoch 404/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7276 - accuracy: 0.7500 - val_loss: 0.6384 - val_accuracy: 0.8333
# Epoch 405/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7330 - accuracy: 0.6979 - val_loss: 0.6337 - val_accuracy: 0.8333
# Epoch 406/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7391 - accuracy: 0.6927 - val_loss: 0.6510 - val_accuracy: 0.8333
# Epoch 407/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7645 - accuracy: 0.7240 - val_loss: 0.6734 - val_accuracy: 0.8333
# Epoch 408/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7385 - accuracy: 0.7083 - val_loss: 0.6908 - val_accuracy: 0.8125
# Epoch 409/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7976 - accuracy: 0.6875 - val_loss: 0.6790 - val_accuracy: 0.8333
# Epoch 410/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7692 - accuracy: 0.7135 - val_loss: 0.6589 - val_accuracy: 0.8542
# Epoch 411/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7211 - accuracy: 0.7240 - val_loss: 0.6405 - val_accuracy: 0.8542
# Epoch 412/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7161 - accuracy: 0.7344 - val_loss: 0.6355 - val_accuracy: 0.8542
# Epoch 413/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6722 - accuracy: 0.7135 - val_loss: 0.6146 - val_accuracy: 0.8750
# Epoch 414/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6621 - accuracy: 0.7292 - val_loss: 0.6018 - val_accuracy: 0.8542
# Epoch 415/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7255 - accuracy: 0.7448 - val_loss: 0.6032 - val_accuracy: 0.8125
# Epoch 416/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6854 - accuracy: 0.7552 - val_loss: 0.6108 - val_accuracy: 0.8125
# Epoch 417/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7165 - accuracy: 0.6979 - val_loss: 0.6052 - val_accuracy: 0.8125
# Epoch 418/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6960 - accuracy: 0.7083 - val_loss: 0.6054 - val_accuracy: 0.7917
# Epoch 419/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6820 - accuracy: 0.7344 - val_loss: 0.6084 - val_accuracy: 0.8125
# Epoch 420/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6438 - accuracy: 0.7448 - val_loss: 0.6488 - val_accuracy: 0.7500
# Epoch 421/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7156 - accuracy: 0.7083 - val_loss: 0.6487 - val_accuracy: 0.7708
# Epoch 422/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6414 - accuracy: 0.7396 - val_loss: 0.6467 - val_accuracy: 0.7917
# Epoch 423/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6715 - accuracy: 0.7500 - val_loss: 0.6273 - val_accuracy: 0.8333
# Epoch 424/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6805 - accuracy: 0.7344 - val_loss: 0.6650 - val_accuracy: 0.7917
# Epoch 425/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6518 - accuracy: 0.7708 - val_loss: 0.6811 - val_accuracy: 0.7708
# Epoch 426/500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.7629 - accuracy: 0.6927 - val_loss: 0.6539 - val_accuracy: 0.7917
# Epoch 427/500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.7541 - accuracy: 0.7031 - val_loss: 0.6602 - val_accuracy: 0.8333
# Epoch 428/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7619 - accuracy: 0.7500 - val_loss: 0.6628 - val_accuracy: 0.8125
# Epoch 429/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7760 - accuracy: 0.6719 - val_loss: 0.6663 - val_accuracy: 0.7917
# Epoch 430/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7900 - accuracy: 0.6667 - val_loss: 0.6751 - val_accuracy: 0.7917
# Epoch 431/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7789 - accuracy: 0.6771 - val_loss: 0.6631 - val_accuracy: 0.8125
# Epoch 432/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6872 - accuracy: 0.7396 - val_loss: 0.6411 - val_accuracy: 0.7917
# Epoch 433/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7012 - accuracy: 0.7500 - val_loss: 0.6146 - val_accuracy: 0.8750
# Epoch 434/500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.6486 - accuracy: 0.7656 - val_loss: 0.5843 - val_accuracy: 0.8958
# Epoch 435/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7110 - accuracy: 0.7500 - val_loss: 0.5840 - val_accuracy: 0.8958
# Epoch 436/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7120 - accuracy: 0.7344 - val_loss: 0.5831 - val_accuracy: 0.8333
# Epoch 437/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6798 - accuracy: 0.7344 - val_loss: 0.5942 - val_accuracy: 0.8333
# Epoch 438/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7067 - accuracy: 0.7240 - val_loss: 0.6148 - val_accuracy: 0.7917
# Epoch 439/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6869 - accuracy: 0.6719 - val_loss: 0.6264 - val_accuracy: 0.7917
# Epoch 440/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6995 - accuracy: 0.7448 - val_loss: 0.6321 - val_accuracy: 0.8125
# Epoch 441/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6887 - accuracy: 0.7656 - val_loss: 0.6332 - val_accuracy: 0.7917
# Epoch 442/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7487 - accuracy: 0.6979 - val_loss: 0.6487 - val_accuracy: 0.7917
# Epoch 443/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7726 - accuracy: 0.6719 - val_loss: 0.6644 - val_accuracy: 0.7708
# Epoch 444/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6910 - accuracy: 0.7812 - val_loss: 0.6581 - val_accuracy: 0.7917
# Epoch 445/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7315 - accuracy: 0.6562 - val_loss: 0.6634 - val_accuracy: 0.7708
# Epoch 446/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7506 - accuracy: 0.6927 - val_loss: 0.6515 - val_accuracy: 0.7917
# Epoch 447/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7326 - accuracy: 0.7188 - val_loss: 0.6341 - val_accuracy: 0.8333
# Epoch 448/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6449 - accuracy: 0.7656 - val_loss: 0.6461 - val_accuracy: 0.8125
# Epoch 449/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6926 - accuracy: 0.7396 - val_loss: 0.6898 - val_accuracy: 0.7500
# Epoch 450/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7547 - accuracy: 0.7188 - val_loss: 0.6771 - val_accuracy: 0.7708
# Epoch 451/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7042 - accuracy: 0.7135 - val_loss: 0.6616 - val_accuracy: 0.7708
# Epoch 452/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7251 - accuracy: 0.6979 - val_loss: 0.6331 - val_accuracy: 0.7917
# Epoch 453/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6942 - accuracy: 0.7344 - val_loss: 0.6385 - val_accuracy: 0.8125
# Epoch 454/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7098 - accuracy: 0.7396 - val_loss: 0.6141 - val_accuracy: 0.8125
# Epoch 455/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7931 - accuracy: 0.6771 - val_loss: 0.6206 - val_accuracy: 0.8333
# Epoch 456/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6976 - accuracy: 0.7552 - val_loss: 0.6312 - val_accuracy: 0.8125
# Epoch 457/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7122 - accuracy: 0.7708 - val_loss: 0.6286 - val_accuracy: 0.8125
# Epoch 458/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7104 - accuracy: 0.7604 - val_loss: 0.6120 - val_accuracy: 0.8333
# Epoch 459/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6691 - accuracy: 0.7812 - val_loss: 0.5996 - val_accuracy: 0.8333
# Epoch 460/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6588 - accuracy: 0.7292 - val_loss: 0.6074 - val_accuracy: 0.8333
# Epoch 461/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7050 - accuracy: 0.7083 - val_loss: 0.6072 - val_accuracy: 0.7708
# Epoch 462/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6437 - accuracy: 0.7917 - val_loss: 0.6182 - val_accuracy: 0.7917
# Epoch 463/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7030 - accuracy: 0.7292 - val_loss: 0.5931 - val_accuracy: 0.8125
# Epoch 464/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7001 - accuracy: 0.7240 - val_loss: 0.6187 - val_accuracy: 0.8333
# Epoch 465/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6726 - accuracy: 0.7552 - val_loss: 0.6257 - val_accuracy: 0.8333
# Epoch 466/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7448 - accuracy: 0.7188 - val_loss: 0.6200 - val_accuracy: 0.7917
# Epoch 467/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6835 - accuracy: 0.7083 - val_loss: 0.6102 - val_accuracy: 0.7917
# Epoch 468/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7806 - accuracy: 0.7344 - val_loss: 0.6360 - val_accuracy: 0.7917
# Epoch 469/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6918 - accuracy: 0.7031 - val_loss: 0.6262 - val_accuracy: 0.8333
# Epoch 470/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6564 - accuracy: 0.7917 - val_loss: 0.6110 - val_accuracy: 0.8125
# Epoch 471/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7274 - accuracy: 0.6979 - val_loss: 0.6348 - val_accuracy: 0.8333
# Epoch 472/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7211 - accuracy: 0.7188 - val_loss: 0.6417 - val_accuracy: 0.8333
# Epoch 473/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7136 - accuracy: 0.7500 - val_loss: 0.6405 - val_accuracy: 0.8542
# Epoch 474/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7399 - accuracy: 0.6875 - val_loss: 0.6416 - val_accuracy: 0.8125
# Epoch 475/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6669 - accuracy: 0.7604 - val_loss: 0.6306 - val_accuracy: 0.8333
# Epoch 476/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7612 - accuracy: 0.6979 - val_loss: 0.6312 - val_accuracy: 0.8125
# Epoch 477/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7319 - accuracy: 0.7031 - val_loss: 0.6339 - val_accuracy: 0.8333
# Epoch 478/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6852 - accuracy: 0.7552 - val_loss: 0.6211 - val_accuracy: 0.7917
# Epoch 479/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6635 - accuracy: 0.7552 - val_loss: 0.6087 - val_accuracy: 0.8125
# Epoch 480/500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.7119 - accuracy: 0.7240 - val_loss: 0.6106 - val_accuracy: 0.8750
# Epoch 481/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7137 - accuracy: 0.7188 - val_loss: 0.6107 - val_accuracy: 0.8750
# Epoch 482/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6386 - accuracy: 0.7604 - val_loss: 0.6000 - val_accuracy: 0.8542
# Epoch 483/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6937 - accuracy: 0.7135 - val_loss: 0.5868 - val_accuracy: 0.8542
# Epoch 484/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6972 - accuracy: 0.7292 - val_loss: 0.6100 - val_accuracy: 0.8542
# Epoch 485/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7240 - accuracy: 0.7344 - val_loss: 0.6106 - val_accuracy: 0.8750
# Epoch 486/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7240 - accuracy: 0.7292 - val_loss: 0.6260 - val_accuracy: 0.8125
# Epoch 487/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7838 - accuracy: 0.6823 - val_loss: 0.6362 - val_accuracy: 0.7708
# Epoch 488/500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.7076 - accuracy: 0.6927 - val_loss: 0.6261 - val_accuracy: 0.7500
# Epoch 489/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6896 - accuracy: 0.7396 - val_loss: 0.6238 - val_accuracy: 0.7500
# Epoch 490/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6853 - accuracy: 0.7552 - val_loss: 0.6202 - val_accuracy: 0.7708
# Epoch 491/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6721 - accuracy: 0.7604 - val_loss: 0.6075 - val_accuracy: 0.7917
# Epoch 492/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7555 - accuracy: 0.6927 - val_loss: 0.6226 - val_accuracy: 0.7917
# Epoch 493/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6733 - accuracy: 0.6979 - val_loss: 0.6381 - val_accuracy: 0.7708
# Epoch 494/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6915 - accuracy: 0.7812 - val_loss: 0.6448 - val_accuracy: 0.7708
# Epoch 495/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6896 - accuracy: 0.7396 - val_loss: 0.6359 - val_accuracy: 0.7917
# Epoch 496/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6629 - accuracy: 0.8281 - val_loss: 0.6277 - val_accuracy: 0.7917
# Epoch 497/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7838 - accuracy: 0.7292 - val_loss: 0.6400 - val_accuracy: 0.7708
# Epoch 498/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7294 - accuracy: 0.7344 - val_loss: 0.6464 - val_accuracy: 0.7708
# Epoch 499/500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.7371 - accuracy: 0.7188 - val_loss: 0.6348 - val_accuracy: 0.8542
# Epoch 500/500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.7317 - accuracy: 0.6771 - val_loss: 0.6263 - val_accuracy: 0.8542
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6263 - accuracy: 0.8542
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd4e8e7a2f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:56: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
# Accuracy [Each Fold]: [0.7916666865348816, 0.8333333134651184, 0.8333333134651184, 0.8125, 0.8541666865348816]
# Accuracy: 0.82
# Sensitivity: 0.9114
# Specificity: 0.7177
# MCC: 0.6492
# Precision: 0.7888
