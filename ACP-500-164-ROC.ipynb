# %% [markdown]
# <a href="https://colab.research.google.com/github/mrzResearchArena/Anticancer-Peptides-CNN/blob/master/ACP-500-164-ROC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### [1]. Google Drive Initialization:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls
# Out:
# bits-164.npy    blosum-740.npy     model-740.png      PyFeat-740-20.npy
# bits-240.npy    bpf-164.npy        PyFeat-164-20.npy  PyFeat-740.npy
# bits-500.npy    bpf-240.npy        PyFeat-164.npy     ROC-240.png
# bits-740.npy    bpf-500.npy        PyFeat-240-20.npy  ROC-500-164.png
# blosum-164.npy  bpf-740.npy        PyFeat-240.npy     ROC-740.png
# blosum-240.npy  model-240.png      PyFeat-500-20.npy  ROC.png
# blosum-500.npy  model-500-164.png  PyFeat-500.npy

# %%
cd 'drive/My Drive/ACP-PyFeat'
# Out:
# /content/drive/My Drive/ACP-PyFeat

# %%
ls
# Out:
# bits-164.npy    blosum-740.npy     model-740.png      PyFeat-740-20.npy
# bits-240.npy    bpf-164.npy        PyFeat-164-20.npy  PyFeat-740.npy
# bits-500.npy    bpf-240.npy        PyFeat-164.npy     ROC-240.png
# bits-740.npy    bpf-500.npy        PyFeat-240-20.npy  ROC-500-164.png
# blosum-164.npy  bpf-740.npy        PyFeat-240.npy     ROC-740.png
# blosum-240.npy  model-240.png      PyFeat-500-20.npy  ROC.png
# blosum-500.npy  model-500-164.png  PyFeat-500.npy

# %% [markdown]
# ### [2]. Load Deep Learning API (Keras):

# %%
# Deep Neural Networks:
import tensorflow as tf; print('We\'re using TF-{}.'.format(tf.__version__))
# import keras; print('We\'re using Keras-{}.'.format(keras.__version__))
from tensorflow.keras.layers import (Input, Dense, Dropout, Flatten, BatchNormalization,
                                     Conv1D, Conv2D, MaxPooling1D, MaxPooling2D,
                                     LSTM, GRU, Embedding, Bidirectional, Concatenate)
from tensorflow.keras.regularizers import (l1, l2, l1_l2)
from tensorflow.keras.optimizers import (RMSprop, Adam, SGD)
from tensorflow.keras.models import (Sequential, Model)

# Core:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import interp
import matplotlib.patches as patches

# Performance:
from sklearn.metrics import (confusion_matrix, classification_report, matthews_corrcoef, precision_score, roc_curve, auc)
from sklearn.model_selection import (StratifiedKFold, KFold, train_test_split)

#Utilities:
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import to_categorical as labelEncoding   # Usages: Y = labelEncoding(Y, dtype=int)
from tensorflow.keras.utils import plot_model                        # Usages: plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=False, expand_nested=True)

#end-import
# Out:
# We're using TF-2.3.0.

# %% [markdown]
# ### [3]. Load Datasets:

# %%
T = 20 # terminus_length

X1train = np.load('bpf-500.npy')
X2train = np.load('bits-500.npy')
X3train = np.load('blosum-500.npy')

X1train = X1train[:,0:T,:]
X2train = X2train[:,0:T,:]
X3train = X3train[:,0:T,:]

print(X1train.shape)
print(X2train.shape)
print(X3train.shape)


print('### --- --- --- --- --- ###')


X1test = np.load('bpf-164.npy')
X2test = np.load('bits-164.npy')
X3test = np.load('blosum-164.npy')

X1test = X1test[:,0:T,:]
X2test = X2test[:,0:T,:]
X3test = X3test[:,0:T,:]

print(X1test.shape)
print(X2test.shape)
print(X3test.shape)

print('### --- --- --- --- --- ###')

# ACP {500, 164}
Ytrain  = [0 for _ in range(250)]
Ytrain += [1 for _ in range(250)]
Ytrain  = np.array(Ytrain)

Ytest  = [0 for _ in range(82)]
Ytest += [1 for _ in range(82)]

Ytrain = labelEncoding(Ytrain, dtype=int)
Ytest  = labelEncoding(Ytest, dtype=int)
# Out:
# (500, 20, 20)
# (500, 20, 31)
# (500, 20, 20)
# ### --- --- --- --- --- ###
# (164, 20, 20)
# (164, 20, 31)
# (164, 20, 20)
# ### --- --- --- --- --- ###

# %%
def lossPlot(results):
    plt.title(label='Loss: Training and Validation')
    plt.plot(results.history['loss'], label='Training Loss')
    plt.plot(results.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
#end-def

def accuracyPlot(results):
    plt.title(label='Accuracy: Training and Validation')
    plt.plot(results.history['accuracy'], label='Training Accuracy')
    plt.plot(results.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()
#end-def

# %% [markdown]
# ### [4]. Generate Model:

# %%
def Network():
    ### Head-1:
    input1 = Input(shape=X1train[0].shape)

    x = Conv1D(filters=16, kernel_size=3, padding='same', data_format='channels_first', activation='relu', kernel_regularizer=l2(l=0.01))(input1)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.70)(x)

    x = Conv1D(filters=8, kernel_size=3, padding='same', data_format='channels_first', activation='relu', kernel_regularizer=l2(l=0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.50)(x)

    head1 = Flatten()(x)


    ### Head-2:
    input2 = Input(shape=X2train[0].shape)

    x = Conv1D(filters=16, kernel_size=3, padding='same', activation='relu', kernel_regularizer=l2(l=0.01))(input2)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.70)(x)

    x = Conv1D(filters=8, kernel_size=3, padding='same', activation='relu', kernel_regularizer=l2(l=0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.50)(x)

    head2 = Flatten()(x)


    ### Head-3:
    input3 = Input(shape=X3train[0].shape)

    x = Conv1D(filters=16, kernel_size=3, padding='same', activation='relu', kernel_regularizer=l2(l=0.01))(input3)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.70)(x)

    x = Conv1D(filters=8, kernel_size=3, padding='same', activation='relu', kernel_regularizer=l2(l=0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.50)(x)

    head3 = Flatten()(x)


    # merge
    merge = Concatenate()([head1, head2, head3])

    
    output = Dense(units=16, activation='relu',)(merge)
    output = BatchNormalization()(output)
    output = Dropout(rate=0.60)(output)
    
    output = Dense(units=8, activation='relu',)(output)
    output = BatchNormalization()(output)
    output = Dropout(rate=0.50)(output)

    output = Dense(units=2, activation='softmax')(output)

    return Model(inputs=[input1, input2, input3], outputs=[output])
#end-def

# %%
model = Network()
model.summary()
plot_model(model, to_file='model-500-164.png', show_shapes=True, show_layer_names=False, expand_nested=True)
# Out:
# Model: "functional_13"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_19 (InputLayer)           [(None, 20, 20)]     0
# __________________________________________________________________________________________________
# input_20 (InputLayer)           [(None, 20, 31)]     0
# __________________________________________________________________________________________________
# input_21 (InputLayer)           [(None, 20, 20)]     0
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 16, 20)       976         input_19[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 20, 16)       1504        input_20[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 20, 16)       976         input_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 16, 20)       80          conv1d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 20, 16)       64          conv1d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 20, 16)       64          conv1d_40[0][0]
# __________________________________________________________________________________________________
# dropout_48 (Dropout)            (None, 16, 20)       0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# dropout_50 (Dropout)            (None, 20, 16)       0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# dropout_52 (Dropout)            (None, 20, 16)       0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 8, 20)        392         dropout_48[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 20, 8)        392         dropout_50[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 20, 8)        392         dropout_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 8, 20)        80          conv1d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 20, 8)        32          conv1d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 20, 8)        32          conv1d_41[0][0]
# __________________________________________________________________________________________________
# dropout_49 (Dropout)            (None, 8, 20)        0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# dropout_51 (Dropout)            (None, 20, 8)        0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# dropout_53 (Dropout)            (None, 20, 8)        0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# flatten_18 (Flatten)            (None, 160)          0           dropout_49[0][0]
# __________________________________________________________________________________________________
# flatten_19 (Flatten)            (None, 160)          0           dropout_51[0][0]
# __________________________________________________________________________________________________
# flatten_20 (Flatten)            (None, 160)          0           dropout_53[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 480)          0           flatten_18[0][0]
#                                                                  flatten_19[0][0]
#                                                                  flatten_20[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 16)           7696        concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 16)           64          dense_18[0][0]
# __________________________________________________________________________________________________
# dropout_54 (Dropout)            (None, 16)           0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 8)            136         dropout_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 8)            32          dense_19[0][0]
# __________________________________________________________________________________________________
# dropout_55 (Dropout)            (None, 8)            0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 2)            18          dropout_55[0][0]
# ==================================================================================================
# Total params: 12,930
# Trainable params: 12,706
# Non-trainable params: 224
# __________________________________________________________________________________________________

# %% [markdown]
# ### [5]. Run Model:

# %%
# Setting epoch and batch number
setEpochNumber     = 200       ### 2,500 performed well!
setBatchSizeNumber = 8


# ROC Curve:
fig1 = plt.figure(figsize=[12,12])
TPR = []
meanFPR = np.linspace(0, 1, 100)


# Compile Model:
model = Network()
model.compile(optimizer=Adam(lr=0.005),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
              # Adam(lr=0.0001)

# Run Model:
results = model.fit(x=[X1train, X2train, X3train],
                        y=Ytrain,
                        validation_data=([X1test, X2test, X3test], Ytest),
                        batch_size=setBatchSizeNumber, epochs=setEpochNumber,
                        verbose=1,
                        callbacks=[])
    

# Evaluate the Model:
accuracy = model.evaluate(x=[X1test, X2test, X3test], y=Ytest)

# Performance Metices:
Yactual = Ytest.argmax(axis=1)
Yp = model.predict([X1test, X2test, X3test])
v = Yp
Yp = Yp.argmax(axis=1)

CM = confusion_matrix(y_pred=Yp, y_true=Yactual)
TN, FP, FN, TP = CM.ravel()


print('Accuracy: {:.2f}'.format(accuracy[1]))
print('MCC: {:.2f}'.format(matthews_corrcoef(y_true=Yactual, y_pred=Yp)))
print('Sensitivity: {0:.4f}'.format(TP / (TP + FN)))
print('Specificity: {0:.4f}'.format(TN / (TN + FP)))
print('Precision: {0:.4f}'.format(precision_score(y_true=Yactual, y_pred=Yp)))


# # Performance Plot
# lossPlot(results)
# accuracyPlot(results)

fpr, tpr, _ = roc_curve(Yactual, v[:,1])
TPR.append(interp(meanFPR, fpr, tpr))
rocauc = auc(fpr, tpr)
# plt.plot(fpr, tpr, lw=2, alpha=0.3, label='(AUC = %0.2f)' % (rocauc))


plt.plot([0,1], [0,1],linestyle = '--',lw = 2,color = 'black')
meanTPR = np.mean(TPR, axis=0)
meanAUC = auc(meanFPR, meanTPR)
plt.plot(meanFPR, meanTPR, color='blue',
        label=r'ROC (AUC = %0.2f )' % (meanAUC),lw=2, alpha=1)

plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic Curve (ROC Curve)')
plt.legend(loc="lower right")
plt.savefig('ROC-500-164.png')
plt.show()
# Out:
# Epoch 1/200
# 63/63 [==============================] - 1s 14ms/step - loss: 1.6632 - accuracy: 0.5540 - val_loss: 1.4998 - val_accuracy: 0.5305
# Epoch 2/200
# 63/63 [==============================] - 1s 9ms/step - loss: 1.4785 - accuracy: 0.5160 - val_loss: 1.4027 - val_accuracy: 0.5244
# Epoch 3/200
# 63/63 [==============================] - 1s 9ms/step - loss: 1.3785 - accuracy: 0.4700 - val_loss: 1.2929 - val_accuracy: 0.5305
# Epoch 4/200
# 63/63 [==============================] - 1s 9ms/step - loss: 1.2500 - accuracy: 0.5160 - val_loss: 1.1857 - val_accuracy: 0.5976
# Epoch 5/200
# 63/63 [==============================] - 1s 10ms/step - loss: 1.1495 - accuracy: 0.5060 - val_loss: 1.0896 - val_accuracy: 0.6341
# Epoch 6/200
# 63/63 [==============================] - 1s 10ms/step - loss: 1.0466 - accuracy: 0.5720 - val_loss: 1.0018 - val_accuracy: 0.6585
# Epoch 7/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.9847 - accuracy: 0.5980 - val_loss: 0.9552 - val_accuracy: 0.6524
# Epoch 8/200
# 63/63 [==============================] - 1s 11ms/step - loss: 0.9540 - accuracy: 0.5900 - val_loss: 0.9066 - val_accuracy: 0.7012
# Epoch 9/200
# 63/63 [==============================] - 1s 11ms/step - loss: 0.9353 - accuracy: 0.5980 - val_loss: 0.8724 - val_accuracy: 0.6707
# Epoch 10/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.8968 - accuracy: 0.6260 - val_loss: 0.8701 - val_accuracy: 0.6829
# Epoch 11/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.8641 - accuracy: 0.6580 - val_loss: 0.8092 - val_accuracy: 0.7073
# Epoch 12/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.8500 - accuracy: 0.6700 - val_loss: 0.8242 - val_accuracy: 0.6829
# Epoch 13/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.8753 - accuracy: 0.6560 - val_loss: 0.8321 - val_accuracy: 0.7073
# Epoch 14/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.8659 - accuracy: 0.6440 - val_loss: 0.8203 - val_accuracy: 0.6829
# Epoch 15/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.8263 - accuracy: 0.6740 - val_loss: 0.7634 - val_accuracy: 0.6890
# Epoch 16/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.7885 - accuracy: 0.7100 - val_loss: 0.7382 - val_accuracy: 0.7439
# Epoch 17/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.8550 - accuracy: 0.6800 - val_loss: 0.7763 - val_accuracy: 0.7073
# Epoch 18/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.8552 - accuracy: 0.6640 - val_loss: 0.7838 - val_accuracy: 0.7073
# Epoch 19/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.7890 - accuracy: 0.6920 - val_loss: 0.7156 - val_accuracy: 0.7195
# Epoch 20/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.7859 - accuracy: 0.6860 - val_loss: 0.7323 - val_accuracy: 0.7256
# Epoch 21/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.8238 - accuracy: 0.6780 - val_loss: 0.7311 - val_accuracy: 0.7439
# Epoch 22/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7892 - accuracy: 0.6940 - val_loss: 0.7188 - val_accuracy: 0.7561
# Epoch 23/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7320 - accuracy: 0.7200 - val_loss: 0.6485 - val_accuracy: 0.7866
# Epoch 24/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7053 - accuracy: 0.7300 - val_loss: 0.6909 - val_accuracy: 0.7378
# Epoch 25/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.7299 - accuracy: 0.7220 - val_loss: 0.7070 - val_accuracy: 0.7256
# Epoch 26/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7300 - accuracy: 0.7200 - val_loss: 0.6433 - val_accuracy: 0.7622
# Epoch 27/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7594 - accuracy: 0.7140 - val_loss: 0.6765 - val_accuracy: 0.7744
# Epoch 28/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7030 - accuracy: 0.7420 - val_loss: 0.6423 - val_accuracy: 0.7683
# Epoch 29/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7072 - accuracy: 0.7240 - val_loss: 0.6199 - val_accuracy: 0.8049
# Epoch 30/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7099 - accuracy: 0.7500 - val_loss: 0.6017 - val_accuracy: 0.8232
# Epoch 31/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7166 - accuracy: 0.7680 - val_loss: 0.6128 - val_accuracy: 0.8354
# Epoch 32/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6451 - accuracy: 0.7760 - val_loss: 0.5844 - val_accuracy: 0.8171
# Epoch 33/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6501 - accuracy: 0.7780 - val_loss: 0.5934 - val_accuracy: 0.7927
# Epoch 34/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6998 - accuracy: 0.7720 - val_loss: 0.5960 - val_accuracy: 0.8110
# Epoch 35/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7186 - accuracy: 0.7360 - val_loss: 0.6119 - val_accuracy: 0.8354
# Epoch 36/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7052 - accuracy: 0.7760 - val_loss: 0.6707 - val_accuracy: 0.7927
# Epoch 37/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7472 - accuracy: 0.7540 - val_loss: 0.7236 - val_accuracy: 0.7500
# Epoch 38/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7441 - accuracy: 0.7420 - val_loss: 0.6688 - val_accuracy: 0.7744
# Epoch 39/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.7403 - accuracy: 0.7480 - val_loss: 0.6175 - val_accuracy: 0.8110
# Epoch 40/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6784 - accuracy: 0.7480 - val_loss: 0.5847 - val_accuracy: 0.8171
# Epoch 41/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6109 - accuracy: 0.8100 - val_loss: 0.5657 - val_accuracy: 0.8232
# Epoch 42/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6745 - accuracy: 0.7740 - val_loss: 0.6019 - val_accuracy: 0.7988
# Epoch 43/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6557 - accuracy: 0.7760 - val_loss: 0.6435 - val_accuracy: 0.7439
# Epoch 44/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6485 - accuracy: 0.7860 - val_loss: 0.5886 - val_accuracy: 0.8293
# Epoch 45/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6483 - accuracy: 0.7780 - val_loss: 0.5898 - val_accuracy: 0.8476
# Epoch 46/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6892 - accuracy: 0.7780 - val_loss: 0.5996 - val_accuracy: 0.8171
# Epoch 47/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7060 - accuracy: 0.7620 - val_loss: 0.6681 - val_accuracy: 0.7805
# Epoch 48/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6737 - accuracy: 0.7940 - val_loss: 0.6043 - val_accuracy: 0.7805
# Epoch 49/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7011 - accuracy: 0.7440 - val_loss: 0.6318 - val_accuracy: 0.8171
# Epoch 50/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6706 - accuracy: 0.7880 - val_loss: 0.5982 - val_accuracy: 0.8049
# Epoch 51/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5905 - accuracy: 0.8120 - val_loss: 0.5805 - val_accuracy: 0.8171
# Epoch 52/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6621 - accuracy: 0.7800 - val_loss: 0.5993 - val_accuracy: 0.8110
# Epoch 53/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6777 - accuracy: 0.7780 - val_loss: 0.5960 - val_accuracy: 0.8232
# Epoch 54/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6890 - accuracy: 0.7580 - val_loss: 0.5957 - val_accuracy: 0.8171
# Epoch 55/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6712 - accuracy: 0.7760 - val_loss: 0.6045 - val_accuracy: 0.8415
# Epoch 56/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6212 - accuracy: 0.8100 - val_loss: 0.5586 - val_accuracy: 0.8354
# Epoch 57/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6706 - accuracy: 0.7960 - val_loss: 0.5652 - val_accuracy: 0.8293
# Epoch 58/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6655 - accuracy: 0.7800 - val_loss: 0.5491 - val_accuracy: 0.8720
# Epoch 59/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6324 - accuracy: 0.7960 - val_loss: 0.5204 - val_accuracy: 0.8537
# Epoch 60/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6792 - accuracy: 0.7660 - val_loss: 0.5605 - val_accuracy: 0.8476
# Epoch 61/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6426 - accuracy: 0.7960 - val_loss: 0.5529 - val_accuracy: 0.8780
# Epoch 62/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6066 - accuracy: 0.8020 - val_loss: 0.5500 - val_accuracy: 0.8354
# Epoch 63/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6228 - accuracy: 0.7880 - val_loss: 0.5622 - val_accuracy: 0.8171
# Epoch 64/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6269 - accuracy: 0.8200 - val_loss: 0.5323 - val_accuracy: 0.8780
# Epoch 65/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6679 - accuracy: 0.7920 - val_loss: 0.5408 - val_accuracy: 0.8415
# Epoch 66/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6615 - accuracy: 0.7860 - val_loss: 0.5414 - val_accuracy: 0.8354
# Epoch 67/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6138 - accuracy: 0.8140 - val_loss: 0.5052 - val_accuracy: 0.8659
# Epoch 68/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6454 - accuracy: 0.7740 - val_loss: 0.5556 - val_accuracy: 0.8415
# Epoch 69/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5920 - accuracy: 0.8200 - val_loss: 0.5254 - val_accuracy: 0.8415
# Epoch 70/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6280 - accuracy: 0.7940 - val_loss: 0.5548 - val_accuracy: 0.8476
# Epoch 71/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6150 - accuracy: 0.8040 - val_loss: 0.5250 - val_accuracy: 0.8598
# Epoch 72/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5975 - accuracy: 0.8060 - val_loss: 0.5291 - val_accuracy: 0.8354
# Epoch 73/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6801 - accuracy: 0.7740 - val_loss: 0.5559 - val_accuracy: 0.8415
# Epoch 74/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6373 - accuracy: 0.7800 - val_loss: 0.5169 - val_accuracy: 0.8598
# Epoch 75/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5997 - accuracy: 0.8120 - val_loss: 0.5354 - val_accuracy: 0.8659
# Epoch 76/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6780 - accuracy: 0.7940 - val_loss: 0.5368 - val_accuracy: 0.8598
# Epoch 77/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6246 - accuracy: 0.8160 - val_loss: 0.5139 - val_accuracy: 0.8537
# Epoch 78/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6450 - accuracy: 0.7960 - val_loss: 0.5191 - val_accuracy: 0.8659
# Epoch 79/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6061 - accuracy: 0.8020 - val_loss: 0.4903 - val_accuracy: 0.8598
# Epoch 80/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5679 - accuracy: 0.8140 - val_loss: 0.5074 - val_accuracy: 0.8415
# Epoch 81/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6320 - accuracy: 0.7960 - val_loss: 0.5222 - val_accuracy: 0.8659
# Epoch 82/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5990 - accuracy: 0.8260 - val_loss: 0.4991 - val_accuracy: 0.8476
# Epoch 83/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6296 - accuracy: 0.7880 - val_loss: 0.5108 - val_accuracy: 0.8537
# Epoch 84/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6280 - accuracy: 0.8040 - val_loss: 0.5184 - val_accuracy: 0.8537
# Epoch 85/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5915 - accuracy: 0.8240 - val_loss: 0.5135 - val_accuracy: 0.8415
# Epoch 86/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6334 - accuracy: 0.7920 - val_loss: 0.5069 - val_accuracy: 0.8659
# Epoch 87/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6062 - accuracy: 0.7900 - val_loss: 0.4912 - val_accuracy: 0.8720
# Epoch 88/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6067 - accuracy: 0.8040 - val_loss: 0.4861 - val_accuracy: 0.8537
# Epoch 89/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6176 - accuracy: 0.8180 - val_loss: 0.5437 - val_accuracy: 0.8415
# Epoch 90/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6276 - accuracy: 0.7860 - val_loss: 0.5972 - val_accuracy: 0.7744
# Epoch 91/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6234 - accuracy: 0.7780 - val_loss: 0.5730 - val_accuracy: 0.8110
# Epoch 92/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6431 - accuracy: 0.7920 - val_loss: 0.5448 - val_accuracy: 0.8049
# Epoch 93/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5848 - accuracy: 0.8000 - val_loss: 0.5428 - val_accuracy: 0.8110
# Epoch 94/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6119 - accuracy: 0.7940 - val_loss: 0.5640 - val_accuracy: 0.7866
# Epoch 95/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5766 - accuracy: 0.7940 - val_loss: 0.5312 - val_accuracy: 0.8476
# Epoch 96/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6085 - accuracy: 0.7880 - val_loss: 0.5314 - val_accuracy: 0.8354
# Epoch 97/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6407 - accuracy: 0.7700 - val_loss: 0.5365 - val_accuracy: 0.8476
# Epoch 98/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6026 - accuracy: 0.8060 - val_loss: 0.5455 - val_accuracy: 0.8415
# Epoch 99/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6695 - accuracy: 0.7620 - val_loss: 0.5562 - val_accuracy: 0.8415
# Epoch 100/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5843 - accuracy: 0.7880 - val_loss: 0.5032 - val_accuracy: 0.8537
# Epoch 101/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5618 - accuracy: 0.8100 - val_loss: 0.4942 - val_accuracy: 0.8415
# Epoch 102/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6034 - accuracy: 0.7860 - val_loss: 0.5009 - val_accuracy: 0.8537
# Epoch 103/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5942 - accuracy: 0.8180 - val_loss: 0.5284 - val_accuracy: 0.8415
# Epoch 104/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6305 - accuracy: 0.7700 - val_loss: 0.5869 - val_accuracy: 0.8049
# Epoch 105/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.7077 - accuracy: 0.7560 - val_loss: 0.5618 - val_accuracy: 0.8415
# Epoch 106/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6223 - accuracy: 0.7980 - val_loss: 0.5497 - val_accuracy: 0.8415
# Epoch 107/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6084 - accuracy: 0.8260 - val_loss: 0.5246 - val_accuracy: 0.8537
# Epoch 108/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6721 - accuracy: 0.7820 - val_loss: 0.5754 - val_accuracy: 0.8110
# Epoch 109/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6316 - accuracy: 0.7840 - val_loss: 0.5294 - val_accuracy: 0.8415
# Epoch 110/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5887 - accuracy: 0.8240 - val_loss: 0.5052 - val_accuracy: 0.8537
# Epoch 111/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5462 - accuracy: 0.8220 - val_loss: 0.5230 - val_accuracy: 0.8537
# Epoch 112/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6054 - accuracy: 0.8060 - val_loss: 0.5240 - val_accuracy: 0.8354
# Epoch 113/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6133 - accuracy: 0.8140 - val_loss: 0.5320 - val_accuracy: 0.8293
# Epoch 114/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5837 - accuracy: 0.8040 - val_loss: 0.5345 - val_accuracy: 0.8354
# Epoch 115/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5935 - accuracy: 0.8140 - val_loss: 0.5297 - val_accuracy: 0.8415
# Epoch 116/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6032 - accuracy: 0.7980 - val_loss: 0.5247 - val_accuracy: 0.8476
# Epoch 117/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6239 - accuracy: 0.7880 - val_loss: 0.5276 - val_accuracy: 0.8415
# Epoch 118/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5940 - accuracy: 0.7940 - val_loss: 0.5217 - val_accuracy: 0.8354
# Epoch 119/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5999 - accuracy: 0.8020 - val_loss: 0.5019 - val_accuracy: 0.8598
# Epoch 120/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6185 - accuracy: 0.7740 - val_loss: 0.5243 - val_accuracy: 0.8537
# Epoch 121/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5967 - accuracy: 0.8000 - val_loss: 0.5124 - val_accuracy: 0.8354
# Epoch 122/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6266 - accuracy: 0.8260 - val_loss: 0.5463 - val_accuracy: 0.8537
# Epoch 123/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6564 - accuracy: 0.7740 - val_loss: 0.5374 - val_accuracy: 0.8537
# Epoch 124/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6149 - accuracy: 0.7960 - val_loss: 0.4811 - val_accuracy: 0.8780
# Epoch 125/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5623 - accuracy: 0.8060 - val_loss: 0.4746 - val_accuracy: 0.8720
# Epoch 126/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5956 - accuracy: 0.7660 - val_loss: 0.5160 - val_accuracy: 0.8354
# Epoch 127/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6224 - accuracy: 0.8100 - val_loss: 0.5099 - val_accuracy: 0.8598
# Epoch 128/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6346 - accuracy: 0.7860 - val_loss: 0.5094 - val_accuracy: 0.8537
# Epoch 129/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5796 - accuracy: 0.8100 - val_loss: 0.4618 - val_accuracy: 0.8659
# Epoch 130/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6041 - accuracy: 0.7800 - val_loss: 0.4750 - val_accuracy: 0.8537
# Epoch 131/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6271 - accuracy: 0.7840 - val_loss: 0.5024 - val_accuracy: 0.8354
# Epoch 132/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5874 - accuracy: 0.8020 - val_loss: 0.4768 - val_accuracy: 0.8659
# Epoch 133/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5837 - accuracy: 0.8060 - val_loss: 0.5245 - val_accuracy: 0.8415
# Epoch 134/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6427 - accuracy: 0.8080 - val_loss: 0.5222 - val_accuracy: 0.8598
# Epoch 135/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6231 - accuracy: 0.8020 - val_loss: 0.5125 - val_accuracy: 0.8720
# Epoch 136/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6295 - accuracy: 0.7820 - val_loss: 0.5013 - val_accuracy: 0.8659
# Epoch 137/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6071 - accuracy: 0.8060 - val_loss: 0.4949 - val_accuracy: 0.8659
# Epoch 138/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6227 - accuracy: 0.7980 - val_loss: 0.4964 - val_accuracy: 0.8720
# Epoch 139/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5905 - accuracy: 0.8180 - val_loss: 0.4801 - val_accuracy: 0.8476
# Epoch 140/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5544 - accuracy: 0.8300 - val_loss: 0.4828 - val_accuracy: 0.8537
# Epoch 141/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5646 - accuracy: 0.8200 - val_loss: 0.4845 - val_accuracy: 0.8476
# Epoch 142/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5923 - accuracy: 0.8040 - val_loss: 0.5012 - val_accuracy: 0.8476
# Epoch 143/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6332 - accuracy: 0.7780 - val_loss: 0.4924 - val_accuracy: 0.8720
# Epoch 144/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6124 - accuracy: 0.7800 - val_loss: 0.4806 - val_accuracy: 0.8720
# Epoch 145/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5671 - accuracy: 0.8120 - val_loss: 0.4598 - val_accuracy: 0.8720
# Epoch 146/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5924 - accuracy: 0.8220 - val_loss: 0.4801 - val_accuracy: 0.8537
# Epoch 147/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5811 - accuracy: 0.7980 - val_loss: 0.4699 - val_accuracy: 0.8598
# Epoch 148/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5917 - accuracy: 0.7880 - val_loss: 0.4959 - val_accuracy: 0.8537
# Epoch 149/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5566 - accuracy: 0.8220 - val_loss: 0.4508 - val_accuracy: 0.8659
# Epoch 150/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5797 - accuracy: 0.7900 - val_loss: 0.5009 - val_accuracy: 0.8537
# Epoch 151/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5759 - accuracy: 0.7980 - val_loss: 0.4846 - val_accuracy: 0.8659
# Epoch 152/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5520 - accuracy: 0.8200 - val_loss: 0.4715 - val_accuracy: 0.8841
# Epoch 153/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5714 - accuracy: 0.8200 - val_loss: 0.4924 - val_accuracy: 0.8659
# Epoch 154/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5884 - accuracy: 0.8180 - val_loss: 0.5012 - val_accuracy: 0.8476
# Epoch 155/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5719 - accuracy: 0.8100 - val_loss: 0.5357 - val_accuracy: 0.7988
# Epoch 156/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5989 - accuracy: 0.7960 - val_loss: 0.5056 - val_accuracy: 0.8293
# Epoch 157/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5743 - accuracy: 0.8140 - val_loss: 0.4973 - val_accuracy: 0.8598
# Epoch 158/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6528 - accuracy: 0.7500 - val_loss: 0.6435 - val_accuracy: 0.7500
# Epoch 159/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6642 - accuracy: 0.7920 - val_loss: 0.5604 - val_accuracy: 0.8293
# Epoch 160/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5846 - accuracy: 0.8240 - val_loss: 0.5242 - val_accuracy: 0.8476
# Epoch 161/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5816 - accuracy: 0.8040 - val_loss: 0.5116 - val_accuracy: 0.8415
# Epoch 162/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6138 - accuracy: 0.7980 - val_loss: 0.5245 - val_accuracy: 0.8537
# Epoch 163/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6349 - accuracy: 0.7700 - val_loss: 0.5181 - val_accuracy: 0.8537
# Epoch 164/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5868 - accuracy: 0.8260 - val_loss: 0.5126 - val_accuracy: 0.8293
# Epoch 165/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6290 - accuracy: 0.7920 - val_loss: 0.4858 - val_accuracy: 0.8841
# Epoch 166/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6004 - accuracy: 0.8040 - val_loss: 0.4912 - val_accuracy: 0.8780
# Epoch 167/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5356 - accuracy: 0.8480 - val_loss: 0.4804 - val_accuracy: 0.8476
# Epoch 168/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6160 - accuracy: 0.7780 - val_loss: 0.5167 - val_accuracy: 0.8476
# Epoch 169/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6311 - accuracy: 0.7860 - val_loss: 0.5250 - val_accuracy: 0.8537
# Epoch 170/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6046 - accuracy: 0.7940 - val_loss: 0.5074 - val_accuracy: 0.8598
# Epoch 171/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6100 - accuracy: 0.7840 - val_loss: 0.4996 - val_accuracy: 0.8476
# Epoch 172/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5700 - accuracy: 0.8060 - val_loss: 0.4822 - val_accuracy: 0.8902
# Epoch 173/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5821 - accuracy: 0.7980 - val_loss: 0.4850 - val_accuracy: 0.8659
# Epoch 174/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5889 - accuracy: 0.8140 - val_loss: 0.5003 - val_accuracy: 0.8659
# Epoch 175/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6373 - accuracy: 0.8160 - val_loss: 0.5244 - val_accuracy: 0.8537
# Epoch 176/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6264 - accuracy: 0.7980 - val_loss: 0.5059 - val_accuracy: 0.8659
# Epoch 177/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5509 - accuracy: 0.8100 - val_loss: 0.4764 - val_accuracy: 0.8720
# Epoch 178/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5786 - accuracy: 0.8200 - val_loss: 0.5051 - val_accuracy: 0.8415
# Epoch 179/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5843 - accuracy: 0.8180 - val_loss: 0.4737 - val_accuracy: 0.8659
# Epoch 180/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5349 - accuracy: 0.8360 - val_loss: 0.4658 - val_accuracy: 0.8598
# Epoch 181/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5745 - accuracy: 0.8020 - val_loss: 0.4744 - val_accuracy: 0.8720
# Epoch 182/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5561 - accuracy: 0.8120 - val_loss: 0.4868 - val_accuracy: 0.8537
# Epoch 183/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5804 - accuracy: 0.8100 - val_loss: 0.4853 - val_accuracy: 0.8415
# Epoch 184/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5878 - accuracy: 0.8000 - val_loss: 0.4801 - val_accuracy: 0.8659
# Epoch 185/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5695 - accuracy: 0.8200 - val_loss: 0.4835 - val_accuracy: 0.8659
# Epoch 186/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6032 - accuracy: 0.8100 - val_loss: 0.4755 - val_accuracy: 0.8720
# Epoch 187/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6007 - accuracy: 0.7960 - val_loss: 0.4969 - val_accuracy: 0.8598
# Epoch 188/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5537 - accuracy: 0.8080 - val_loss: 0.4885 - val_accuracy: 0.8354
# Epoch 189/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5535 - accuracy: 0.8260 - val_loss: 0.4805 - val_accuracy: 0.8720
# Epoch 190/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6348 - accuracy: 0.7820 - val_loss: 0.5322 - val_accuracy: 0.8293
# Epoch 191/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5787 - accuracy: 0.8000 - val_loss: 0.5258 - val_accuracy: 0.8415
# Epoch 192/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6133 - accuracy: 0.8040 - val_loss: 0.5165 - val_accuracy: 0.8537
# Epoch 193/200
# 63/63 [==============================] - 1s 10ms/step - loss: 0.6204 - accuracy: 0.8020 - val_loss: 0.5222 - val_accuracy: 0.8415
# Epoch 194/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5304 - accuracy: 0.8240 - val_loss: 0.5493 - val_accuracy: 0.8049
# Epoch 195/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6408 - accuracy: 0.7860 - val_loss: 0.5342 - val_accuracy: 0.8415
# Epoch 196/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5786 - accuracy: 0.8120 - val_loss: 0.4855 - val_accuracy: 0.8659
# Epoch 197/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6083 - accuracy: 0.8220 - val_loss: 0.5201 - val_accuracy: 0.8293
# Epoch 198/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5724 - accuracy: 0.7980 - val_loss: 0.4862 - val_accuracy: 0.8476
# Epoch 199/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6199 - accuracy: 0.7980 - val_loss: 0.5039 - val_accuracy: 0.8476
# Epoch 200/200
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6152 - accuracy: 0.7920 - val_loss: 0.5096 - val_accuracy: 0.8293
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5096 - accuracy: 0.8293
# Accuracy: 0.83
# MCC: 0.68
# Sensitivity: 0.9390
# Specificity: 0.7195
# Precision: 0.7700
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:53: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead
