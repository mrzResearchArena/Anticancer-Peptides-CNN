# %% [markdown]
# <a href="https://colab.research.google.com/github/mrzResearchArena/Anticancer-Peptides-CNN/blob/master/ACP-500-164-ROC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### [1]. Google Drive Initialization:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd 'drive/My Drive/ACP-PyFeat'
# Out:
# /content/drive/My Drive/ACP-PyFeat

# %%
ls
# Out:
# bits-164.npy    blosum-740.npy     model-740.png      PyFeat-740-20.npy
# bits-240.npy    bpf-164.npy        PyFeat-164-20.npy  PyFeat-740.npy
# bits-500.npy    bpf-240.npy        PyFeat-164.npy     ROC-240.png
# bits-740.npy    bpf-500.npy        PyFeat-240-20.npy  ROC-500-164.png
# blosum-164.npy  bpf-740.npy        PyFeat-240.npy     ROC-740.png
# blosum-240.npy  model-240.png      PyFeat-500-20.npy  ROC.png
# blosum-500.npy  model-500-164.png  PyFeat-500.npy

# %% [markdown]
# ### [2]. Load Deep Learning API (Keras):

# %%
# Deep Neural Networks:
import tensorflow as tf; print('We\'re using TF-{}.'.format(tf.__version__))
# import keras; print('We\'re using Keras-{}.'.format(keras.__version__))
from tensorflow.keras.layers import (Input, Dense, Dropout, Flatten, BatchNormalization,
                                     Conv1D, Conv2D, MaxPooling1D, MaxPooling2D,
                                     LSTM, GRU, Embedding, Bidirectional, Concatenate)
from tensorflow.keras.regularizers import (l1, l2, l1_l2)
from tensorflow.keras.optimizers import (RMSprop, Adam, SGD)
from tensorflow.keras.models import (Sequential, Model)

# Core:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import interp
import matplotlib.patches as patches

# Performance:
from sklearn.metrics import (confusion_matrix, classification_report, matthews_corrcoef, precision_score, roc_curve, auc)
from sklearn.model_selection import (StratifiedKFold, KFold, train_test_split)

#Utilities:
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import to_categorical as labelEncoding   # Usages: Y = labelEncoding(Y, dtype=int)
from tensorflow.keras.utils import plot_model                        # Usages: plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=False, expand_nested=True)

#end-import
# Out:
# We're using TF-2.3.0.

# %% [markdown]
# ### [3]. Load Datasets:

# %%
T = 20 # terminus_length

X1train = np.load('bpf-500.npy')
X2train = np.load('bits-500.npy')
X3train = np.load('blosum-500.npy')

X1train = X1train[:,0:T,:]
X2train = X2train[:,0:T,:]
X3train = X3train[:,0:T,:]

print(X1train.shape)
print(X2train.shape)
print(X3train.shape)


print('### --- --- --- --- --- ###')


X1test = np.load('bpf-164.npy')
X2test = np.load('bits-164.npy')
X3test = np.load('blosum-164.npy')

X1test = X1test[:,0:T,:]
X2test = X2test[:,0:T,:]
X3test = X3test[:,0:T,:]

print(X1test.shape)
print(X2test.shape)
print(X3test.shape)

print('### --- --- --- --- --- ###')

# ACP {500, 164}
Ytrain  = [0 for _ in range(250)]
Ytrain += [1 for _ in range(250)]
Ytrain  = np.array(Ytrain)

Ytest  = [0 for _ in range(82)]
Ytest += [1 for _ in range(82)]

Ytrain = labelEncoding(Ytrain, dtype=int)
Ytest  = labelEncoding(Ytest, dtype=int)
# Out:
# (500, 20, 20)
# (500, 20, 31)
# (500, 20, 20)
# ### --- --- --- --- --- ###
# (164, 20, 20)
# (164, 20, 31)
# (164, 20, 20)
# ### --- --- --- --- --- ###

# %%
def lossPlot(results):
    plt.title(label='Loss: Training and Validation')
    plt.plot(results.history['loss'], label='Training Loss')
    plt.plot(results.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
#end-def

def accuracyPlot(results):
    plt.title(label='Accuracy: Training and Validation')
    plt.plot(results.history['accuracy'], label='Training Accuracy')
    plt.plot(results.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()
#end-def

# %% [markdown]
# ### [4]. Generate Model:

# %%
def Network():
    ### Head-1:
    input1 = Input(shape=X1train[0].shape)

    x = Conv1D(filters=16, kernel_size=4, padding='same', data_format='channels_first', activation='relu', kernel_regularizer=l2(l=0.01))(input1)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.70)(x)

    x = Conv1D(filters=8, kernel_size=3, padding='same', data_format='channels_first', activation='relu', kernel_regularizer=l2(l=0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.60)(x)

    head1 = Flatten()(x)


    ### Head-2:
    input2 = Input(shape=X2train[0].shape)

    x = Conv1D(filters=8, kernel_size=4, padding='same', data_format='channels_first', activation='relu', kernel_regularizer=l2(l=0.01))(input2)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.70)(x)

    x = Conv1D(filters=6, kernel_size=3, padding='same', data_format='channels_first', activation='relu', kernel_regularizer=l2(l=0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.60)(x)

    head2 = Flatten()(x)


    ### Head-3:
    input3 = Input(shape=X3train[0].shape)

    x = Conv1D(filters=16, kernel_size=4, padding='same', data_format='channels_first', activation='relu', kernel_regularizer=l2(l=0.01))(input3)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.70)(x)

    x = Conv1D(filters=8, kernel_size=3, padding='same', data_format='channels_first', activation='relu', kernel_regularizer=l2(l=0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(rate=0.60)(x)

    head3 = Flatten()(x)


    # merge
    merge = Concatenate()([head1, head2, head3])

    
    output = Dense(units=16, activation='relu',)(merge)
    output = BatchNormalization()(output)
    output = Dropout(rate=0.60)(output)
    
    output = Dense(units=8, activation='relu',)(output)
    output = BatchNormalization()(output)
    output = Dropout(rate=0.50)(output)

    output = Dense(units=2, activation='softmax')(output)

    return Model(inputs=[input1, input2, input3], outputs=[output])
#end-def

# %%
model = Network()
model.summary()
plot_model(model, to_file='model-500-164.png', show_shapes=True, show_layer_names=False, expand_nested=True)
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 20, 20)]     0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 20, 31)]     0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 20, 20)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 16, 20)       1296        input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 8, 31)        648         input_2[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 16, 20)       1296        input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 16, 20)       80          conv1d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 8, 31)        124         conv1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 20)       80          conv1d_4[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 16, 20)       0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8, 31)        0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 16, 20)       0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 8, 20)        392         dropout[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 6, 31)        150         dropout_2[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 8, 20)        392         dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 8, 20)        80          conv1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 6, 31)        124         conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 20)        80          conv1d_5[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8, 20)        0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 6, 31)        0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 8, 20)        0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 160)          0           dropout_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 186)          0           dropout_3[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 160)          0           dropout_5[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 506)          0           flatten[0][0]
#                                                                  flatten_1[0][0]
#                                                                  flatten_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 16)           8112        concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16)           64          dense[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16)           0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8)            136         dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8)            32          dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 8)            0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            18          dropout_7[0][0]
# ==================================================================================================
# Total params: 13,104
# Trainable params: 12,772
# Non-trainable params: 332
# __________________________________________________________________________________________________

# %% [markdown]
# ### [5]. Run Model:

# %%
# Setting epoch and batch number
setEpochNumber     = 1000       ### 2,500 performed well!
setBatchSizeNumber = 8


# ROC Curve:
fig1 = plt.figure(figsize=[12,12])
TPR = []
meanFPR = np.linspace(0, 1, 100)


# Compile Model:
model = Network()
model.compile(optimizer=Adam(lr=0.005),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
              # Adam(lr=0.0001)

# Run Model:
results = model.fit(x=[X1train, X2train, X3train],
                        y=Ytrain,
                        validation_data=([X1test, X2test, X3test], Ytest),
                        batch_size=setBatchSizeNumber, epochs=setEpochNumber,
                        verbose=1,
                        callbacks=[])
    

# Evaluate the Model:
accuracy = model.evaluate(x=[X1test, X2test, X3test], y=Ytest)

# Performance Metices:
Yactual = Ytest.argmax(axis=1)
Yp = model.predict([X1test, X2test, X3test])
v = Yp
Yp = Yp.argmax(axis=1)

CM = confusion_matrix(y_pred=Yp, y_true=Yactual)
TN, FP, FN, TP = CM.ravel()


print('Accuracy: {:.2f}'.format(accuracy[1]))
print('MCC: {:.2f}'.format(matthews_corrcoef(y_true=Yactual, y_pred=Yp)))
print('Sensitivity: {0:.4f}'.format(TP / (TP + FN)))
print('Specificity: {0:.4f}'.format(TN / (TN + FP)))
print('Precision: {0:.4f}'.format(precision_score(y_true=Yactual, y_pred=Yp)))


# # Performance Plot
# lossPlot(results)
# accuracyPlot(results)

fpr, tpr, _ = roc_curve(Yactual, v[:,1])
TPR.append(interp(meanFPR, fpr, tpr))
rocauc = auc(fpr, tpr)
# plt.plot(fpr, tpr, lw=2, alpha=0.3, label='(AUC = %0.2f)' % (rocauc))


plt.plot([0,1], [0,1],linestyle = '--',lw = 2,color = 'black')
meanTPR = np.mean(TPR, axis=0)
meanAUC = auc(meanFPR, meanTPR)
plt.plot(meanFPR, meanTPR, color='blue',
        label=r'ROC (AUC = %0.2f )' % (meanAUC),lw=2, alpha=1)

plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic Curve (ROC Curve)')
plt.legend(loc="lower right")
plt.savefig('ROC-500-164.png')
plt.show()
# Out:
# Epoch 1/1000
# 63/63 [==============================] - 1s 14ms/step - loss: 1.5082 - accuracy: 0.4980 - val_loss: 1.4038 - val_accuracy: 0.5549
# Epoch 2/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 1.3860 - accuracy: 0.4900 - val_loss: 1.3200 - val_accuracy: 0.5366
# Epoch 3/1000
# 63/63 [==============================] - 1s 10ms/step - loss: 1.2789 - accuracy: 0.5340 - val_loss: 1.2157 - val_accuracy: 0.6098
# Epoch 4/1000
# 63/63 [==============================] - 1s 10ms/step - loss: 1.1723 - accuracy: 0.5360 - val_loss: 1.1151 - val_accuracy: 0.5915
# Epoch 5/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 1.0791 - accuracy: 0.5600 - val_loss: 1.0638 - val_accuracy: 0.5000
# Epoch 6/1000
# 63/63 [==============================] - 1s 10ms/step - loss: 1.0275 - accuracy: 0.5460 - val_loss: 1.0099 - val_accuracy: 0.5000
# Epoch 7/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.9972 - accuracy: 0.5020 - val_loss: 0.9691 - val_accuracy: 0.5000
# Epoch 8/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.9358 - accuracy: 0.5220 - val_loss: 0.9093 - val_accuracy: 0.4878
# Epoch 9/1000
# 63/63 [==============================] - 1s 10ms/step - loss: 0.8881 - accuracy: 0.5620 - val_loss: 0.8858 - val_accuracy: 0.5000
# Epoch 10/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.8572 - accuracy: 0.5720 - val_loss: 0.8394 - val_accuracy: 0.5671
# Epoch 11/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.8379 - accuracy: 0.5540 - val_loss: 0.8073 - val_accuracy: 0.5915
# Epoch 12/1000
# 63/63 [==============================] - 1s 10ms/step - loss: 0.8010 - accuracy: 0.6060 - val_loss: 0.8047 - val_accuracy: 0.5610
# Epoch 13/1000
# 63/63 [==============================] - 1s 10ms/step - loss: 0.8006 - accuracy: 0.5980 - val_loss: 0.8190 - val_accuracy: 0.5305
# Epoch 14/1000
# 63/63 [==============================] - 1s 10ms/step - loss: 0.8335 - accuracy: 0.5620 - val_loss: 0.8161 - val_accuracy: 0.5732
# Epoch 15/1000
# 63/63 [==============================] - 1s 10ms/step - loss: 0.8155 - accuracy: 0.5640 - val_loss: 0.8046 - val_accuracy: 0.5488
# Epoch 16/1000
# 63/63 [==============================] - 1s 10ms/step - loss: 0.
1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5535 - accuracy: 0.8040 - val_loss: 0.4856 - val_accuracy: 0.8476
# Epoch 323/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5856 - accuracy: 0.7900 - val_loss: 0.5255 - val_accuracy: 0.8110
# Epoch 324/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6202 - accuracy: 0.7680 - val_loss: 0.5419 - val_accuracy: 0.7988
# Epoch 325/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6136 - accuracy: 0.7780 - val_loss: 0.5209 - val_accuracy: 0.8476
# Epoch 326/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5625 - accuracy: 0.8140 - val_loss: 0.5102 - val_accuracy: 0.8293
# Epoch 327/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6054 - accuracy: 0.7780 - val_loss: 0.6328 - val_accuracy: 0.7195
# Epoch 328/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6127 - accuracy: 0.7780 - val_loss: 0.5624 - val_accuracy: 0.8049
# Epoch 329/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5884 - accuracy: 0.7980 - val_loss: 0.5435 - val_accuracy: 0.8171
# Epoch 330/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6112 - accuracy: 0.7880 - val_loss: 0.5647 - val_accuracy: 0.7744
# Epoch 331/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5878 - accuracy: 0.7980 - val_loss: 0.5288 - val_accuracy: 0.7866
# Epoch 332/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5582 - accuracy: 0.7920 - val_loss: 0.5530 - val_accuracy: 0.7805
# Epoch 333/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5818 - accuracy: 0.7880 - val_loss: 0.5213 - val_accuracy: 0.8232
# Epoch 334/1000
# ...
# Epoch 893/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6347 - accuracy: 0.7480 - val_loss: 0.5027 - val_accuracy: 0.8293
# Epoch 894/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5632 - accuracy: 0.7960 - val_loss: 0.4850 - val_accuracy: 0.8232
# Epoch 895/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5161 - accuracy: 0.8080 - val_loss: 0.4952 - val_accuracy: 0.8171
# Epoch 896/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6040 - accuracy: 0.7860 - val_loss: 0.5618 - val_accuracy: 0.7744
# Epoch 897/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5890 - accuracy: 0.7800 - val_loss: 0.4802 - val_accuracy: 0.8110
# Epoch 898/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5710 - accuracy: 0.7780 - val_loss: 0.4720 - val_accuracy: 0.8537
# Epoch 899/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5842 - accuracy: 0.8000 - val_loss: 0.5043 - val_accuracy: 0.7988
# Epoch 900/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.6033 - accuracy: 0.7540 - val_loss: 0.5183 - val_accuracy: 0.8110
# Epoch 901/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5603 - accuracy: 0.8240 - val_loss: 0.5201 - val_accuracy: 0.8049
# Epoch 902/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5755 - accuracy: 0.7540 - val_loss: 0.4984 - val_accuracy: 0.7927
# Epoch 903/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5761 - accuracy: 0.7820 - val_loss: 0.4888 - val_accuracy: 0.8415
# Epoch 904/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5758 - accuracy: 0.7680 - val_loss: 0.4791 - val_accuracy: 0.8171
# Epoch 905/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5765 - accuracy: 0.7980 - val_loss: 0.5356 - val_accuracy: 0.7744
# Epoch 906/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5729 - accuracy: 0.8000 - val_loss: 0.4836 - val_accuracy: 0.8293
# Epoch 907/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5390 - accuracy: 0.8000 - val_loss: 0.4716 - val_accuracy: 0.8354
# Epoch 908/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5712 - accuracy: 0.7800 - val_loss: 0.4749 - val_accuracy: 0.8354
# Epoch 909/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5754 - accuracy: 0.7920 - val_loss: 0.4801 - val_accuracy: 0.8476
# Epoch 910/1000
# 63/63 [==============================] - 1s 9ms/step - loss: 0.5470 - accuracy: 0.8220 - val_loss: 0.4924 - val_accuracy: 0.8354
# Epoch 911/1000
# 63/63 [==============================] - 1s 10ms/step - loss: 0.